# %%
import os 
import random
import numpy as np 
import pandas as pd
import pyspark 
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.ml.feature import Normalizer, StandardScaler, VectorAssembler, StringIndexer
from pyspark.ml.clustering import KMeans
from pyspark.ml.evaluation import ClusteringEvaluator
from tqdm import tqdm
import ujson
import spotipy
import spotipy.util

# %%
#Kafka server address
SERVER = 'localhost:9092'

# %%
#Topic name
TOPIC = 'playlist'

# %%
#Connectors between Spark and Kafka. 
#You need the connector to do the connection between the docker containing the kafka and the spark on the local machine.
#You can download the connector here: https://mvnrepository.com/
#Make sure that you are downloading the .jar that is compatible with the versions that are intalled in your machine.
spark_jars = ("{},{},{},{},{}".format(os.getcwd()+ "/jars/commons-pool2-2.12.0.jar",
                                      os.getcwd()+ "/jars/kafka-clients-3.7.0.jar",
                                      os.getcwd()+ "/jars/spark-sql-kafka-0-10_2.12-3.5.1.jar",
                                      os.getcwd()+ "/jars/spark-streaming-kafka-0-10_2.12-3.5.1.jar",
                                      os.getcwd()+ "/jars/spark-token-provider-kafka-0-10_2.12-3.5.1.jar"))

# %%
spark_jars
# Out:
# 'c:\\Data_Science\\Study-Projects\\Python-Projects\\Recommender-system/jars/commons-pool2-2.12.0.jar,c:\\Data_Science\\Study-Projects\\Python-Projects\\Recommender-system/jars/kafka-clients-3.7.0.jar,c:\\Data_Science\\Study-Projects\\Python-Projects\\Recommender-system/jars/spark-sql-kafka-0-10_2.12-3.5.1.jar,c:\\Data_Science\\Study-Projects\\Python-Projects\\Recommender-system/jars/spark-streaming-kafka-0-10_2.12-3.5.1.jar,c:\\Data_Science\\Study-Projects\\Python-Projects\\Recommender-system/jars/spark-token-provider-kafka-0-10_2.12-3.5.1.jar'

# %% [markdown]
# ## At this moment, we're gonna start the Spark Session. If you have the all the environment variables correctly set, you wont experience a erro in this step. If you have an issue with that, before you start the Spark session, run the following code:
# ### os.environ['PYSPARK_PYTHON'] = sys.executable
# ### os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable
#
# ## This must fix the error.

# %%
spark = SparkSession.builder.config("spark.jars", spark_jars).appName("Recommender-System").getOrCreate()

# %%
spark.sparkContext.setLogLevel('ERROR')

# %%
#We use the Spark Streaming to read the data streaming of Kafka and save the dataframe 
df = spark \
        .readStream \
        .format("kafka") \
        .option("kafka.bootstrap.servers", SERVER) \
        .option("subscribe", TOPIC) \
        .option("startingOffsets", "latest") \
        .load()

# %%
#Select the timestamp column and save as string in a new dataframe 
df1 = df.selectExpr("CAST(value as STRING)","timestamp")

# %%
#We define a schema with the name and type of each column 

def_schema = "order_id INT, id STRING, name STRING, genre STRING, popularity INT, duration_ms DOUBLE, " \
             + "artists STRING, id_artists STRING, release_date STRING, " \
             + "danceability DOUBLE,energy DOUBLE, key INT, loudness DOUBLE, " \
             + "mode INT,speechiness DOUBLE," \
             + "acousticness DOUBLE, instrumentalness DOUBLE, liveness DOUBLE, " \
             + "valence DOUBLE, tempo DOUBLE, time_signature DOUBLE"

# %%
def_schema
# Out:
# 'order_id INT, id STRING, name STRING, genre STRING, popularity INT, duration_ms DOUBLE, artists STRING, id_artists STRING, release_date STRING, danceability DOUBLE,energy DOUBLE, key INT, loudness DOUBLE, mode INT,speechiness DOUBLE,acousticness DOUBLE, instrumentalness DOUBLE, liveness DOUBLE, valence DOUBLE, tempo DOUBLE, time_signature DOUBLE'

# %%
#Selecting the data streaming accordingly with the schema and save in a new dataframe

df2 = df1.select(from_csv(col("value"), def_schema).alias("song"), "timestamp")

# %%
#Creating a view in the memory of Spark and we visualize the schema 
df3 = df2.select("song.*","timestamp")
df3.createOrReplaceTempView("df3_View");
df3.printSchema()
# Out:
# root
#  |-- order_id: integer (nullable = true)
#  |-- id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- genre: string (nullable = true)
#  |-- popularity: integer (nullable = true)
#  |-- duration_ms: double (nullable = true)
#  |-- artists: string (nullable = true)
#  |-- id_artists: string (nullable = true)
#  |-- release_date: string (nullable = true)
#  |-- danceability: double (nullable = true)
#  |-- energy: double (nullable = true)
#  |-- key: integer (nullable = true)
#  |-- loudness: double (nullable = true)
#  |-- mode: integer (nullable = true)
#  |-- speechiness: double (nullable = true)
#  |-- acousticness: double (nullable = true)
#  |-- instrumentalness: double (nullable = true)
#  |-- liveness: double (nullable = true)
#  |-- valence: double (nullable = true)
#  |-- tempo: double (nullable = true)
#  |-- time_signature: double (nullable = true)
#  |-- timestamp: timestamp (nullable = true)

# %%
#Select the data with the songs of stream 
music_stream = spark.sql("SELECT * FROM df3_View")

# %%
#We cannot see yet, because we have to generate the stream of the Spark Streaming 
#Let's create the stream data on the Spark Streaming 

musics_stream_spark = music_stream \
        .writeStream \
        .trigger(processingTime= '5 seconds') \
        .outputMode("append") \
        .option("truncate","false") \
        .format("memory") \
        .queryName("tabela_spark") \
        .start()

musics_stream_spark.awaitTermination(1)

#The data producer created earlier in the "Real-Time-Data-Producer" must be running and connected with kafka
# Out:
# False

# %%
# Select the songs of Spark Stream table 
spark_songs = spark.sql("SELECT * FROM tabela_spark")

# %%
spark_songs.show(5)
# Out:
# +--------+--------------------+--------------------+--------------------+----------+-----------+-------------+--------------------+--------------------+------------+------+----+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+--------------------+
# |order_id|                  id|                name|               genre|popularity|duration_ms|      artists|          id_artists|        release_date|danceability|energy| key|loudness|mode|speechiness|acousticness|instrumentalness|liveness|valence|  tempo|time_signature|           timestamp|
# +--------+--------------------+--------------------+--------------------+----------+-----------+-------------+--------------------+--------------------+------------+------+----+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+--------------------+
# |      76|3FmS1F9CSpVoHIMss...|       Red Dragonfly|experimental hip hop|         0|   282624.0|  Black Taffy|0Y9vfLdeXoP0Mu1rL...|          2018-07-26|       0.181| 0.355|   5| -13.951|   1|     0.0368|       0.171|           0.729|   0.321|  0.134|156.977|           3.0|2024-03-13 10:40:...|
# |      77|47xKNeYXHnsFcISHz...|Searching For Memory|  african electronic|      NULL|       15.0|       281714|        Lamin Fofana|6j6rR9uFQ6yYMDcxm...|        NULL| 0.324|NULL|     5.0|NULL|        0.0|      0.0525|           0.946|   0.911|  0.102| 0.0473|        105.03|2024-03-13 10:40:...|
# |      78|5Ov9SR4f9SzJWkNQy...|Far From the Eyes...|                 nan|         0|   329639.0|   C.L.A.W.S.|3LBsNwoZrEkeaSK9V...|          2018-07-27|        0.65| 0.918|  11|  -6.898|   0|     0.0573|      0.0767|           0.818|   0.145|  0.279|115.992|           4.0|2024-03-13 10:40:...|
# |      79|07ZIVNs0d8TQqoVfW...|       January's End|                 nan|         0|   408248.0|Nigil Caenaan|4RjBcw1cZ7lc9luFv...|          2018-07-26|       0.786| 0.855|   1|  -7.625|   1|     0.0596|     0.00633|           0.883|   0.111| 0.0373|134.006|           4.0|2024-03-13 10:40:...|
# |      80|3EXE6xuaGxSwgW9p2...|          Around You|                 nan|        30|   333559.0|Zane Schaffer|1stp6XCHbjsyVmOYG...|          2018-07-14|       0.743|  0.52|   1| -13.847|   1|      0.063|      0.0305|           0.827|   0.205|  0.175|117.995|           4.0|2024-03-13 10:40:...|
# +--------+--------------------+--------------------+--------------------+----------+-----------+-------------+--------------------+--------------------+------------+------+----+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+--------------------+
# only showing top 5 rows

# %%
#We can see just a few columns, for example
spark_songs.select('order_id','id','name','genre','popularity','duration_ms','artists').show(5)
# Out:
# +--------+--------------------+--------------------+--------------------+----------+-----------+-------------+
# |order_id|                  id|                name|               genre|popularity|duration_ms|      artists|
# +--------+--------------------+--------------------+--------------------+----------+-----------+-------------+
# |      76|3FmS1F9CSpVoHIMss...|       Red Dragonfly|experimental hip hop|         0|   282624.0|  Black Taffy|
# |      77|47xKNeYXHnsFcISHz...|Searching For Memory|  african electronic|      NULL|       15.0|       281714|
# |      78|5Ov9SR4f9SzJWkNQy...|Far From the Eyes...|                 nan|         0|   329639.0|   C.L.A.W.S.|
# |      79|07ZIVNs0d8TQqoVfW...|       January's End|                 nan|         0|   408248.0|Nigil Caenaan|
# |      80|3EXE6xuaGxSwgW9p2...|          Around You|                 nan|        30|   333559.0|Zane Schaffer|
# +--------+--------------------+--------------------+--------------------+----------+-----------+-------------+
# only showing top 5 rows

# %%
spark_songs.count()
# Out:
# 56

# %% [markdown]
# ## Wait a while till the data table have a few songs

# %% [markdown]
# # Now that the Data Stream is running and we can collect the intel, we proceed to extract the data info of user. In this project, i will be using a playlist based on my liked musics on the Spotify

# %%
#Put your Spotify API key
os.environ["SPOTIPY_CLIENT_ID"] = #YourClientID
os.environ["SPOTIPY_CLIENT_SECRET"] = #YourClientSecret
os.environ["SPOTIPY_REDIRECT_URI"] = 'http://localhost:7777/callback'

# %%
#Extraction scope of users preferences 
scope = 'user-library-read'

# %%
#Spotify e-mail used 
username = #YourEmail

# %%
token = spotipy.util.prompt_for_user_token(username, scope)

# %%
spotify = spotipy.Spotify(auth= token)

# %%
#Extract till 50 songs of the user's favorites list  
saved_tracks = spotify.current_user_saved_tracks(limit = 50)

# %%
#function to extract attributes of user's song list
def select_features(track_response):
    return{
        'id':str(track_response['track']['id']),
        'id_artists':str(track_response['track']['artists'][0]['id']),
        'name':str(track_response['track']['name']),
        'artists':[artist['name'] for artist in track_response['track']['artists']],
        'popularity':track_response['track']['popularity']
    }

# %%
tracks = [select_features(track) for track in saved_tracks['items']]

# %%
tracks
# Out:
# [{'id': '56sk7jBpZV0CD31G9hEU3b',
#   'id_artists': '2xiIXseIJcq3nG7C8fHeBj',
#   'name': 'Animal I Have Become',
#   'artists': ['Three Days Grace'],
#   'popularity': 77},
#  {'id': '7piw04hPQZ1OHZ9Fq9JOXR',
#   'id_artists': '2xiIXseIJcq3nG7C8fHeBj',
#   'name': 'Time of Dying',
#   'artists': ['Three Days Grace'],
#   'popularity': 68},
#  {'id': '3HE50TVRquwXe9yv2HFoNL',
#   'id_artists': '2xiIXseIJcq3nG7C8fHeBj',
#   'name': 'Never Too Late',
#   'artists': ['Three Days Grace'],
#   'popularity': 71},
#  {'id': '0M955bMOoilikPXwKLYpoi',
#   'id_artists': '2xiIXseIJcq3nG7C8fHeBj',
#   'name': 'I Hate Everything About You',
#   'artists': ['Three Days Grace'],
#   'popularity': 78},
#  {'id': '1nltpRhEiXikwDlVn4UADk',
#   'id_artists': '246dkjvS1zLTtiykXe5h60',
#   'name': 'One Right Now (with The Weeknd)',
#   'artists': ['Post Malone', 'The Weeknd'],
#   'popularity': 71},
#  {'id': '5Ja2u1FPlVxrxeMWEa2dcn',
#   'id_artists': '246dkjvS1zLTtiykXe5h60',
#   'name': 'When I’m Alone',
#   'artists': ['Post Malone'],
#   'popularity': 57},
#  {'id': '1D2L6MefbXon28PzIk9I3r',
#   'id_artists': '246dkjvS1zLTtiykXe5h60',
#   'name': '92 Explorer',
#   'artists': ['Post Malone'],
#   'popularity': 69},
#  {'id': '5VuxWXbt7XENQCtE9TzpTv',
#   'id_artists': '246dkjvS1zLTtiykXe5h60',
#   'name': 'Spoil My Night (feat. Swae Lee)',
#   'artists': ['Post Malone', 'Swae Lee'],
#   'popularity': 66},
#  {'id': '7dt6x5M1jzdTEt8oCbisTK',
#   'id_artists': '246dkjvS1zLTtiykXe5h60',
#   'name': 'Better Now',
#   'artists': ['Post Malone'],
#   'popularity': 82},
#  {'id': '0e7ipj03S05BNilyu5bRzt',
#   'id_artists': '246dkjvS1zLTtiykXe5h60',
#   'name': 'rockstar (feat. 21 Savage)',
#   'artists': ['Post Malone', '21 Savage'],
#   'popularity': 84},
#  {'id': '5QO79kh1waicV47BqGRL3g',
#   'id_artists': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'name': 'Save Your Tears',
#   'artists': ['The Weeknd'],
#   'popularity': 89},
#  {'id': '7GUhiAHLoVy1V8ucQuZ3CB',
#   'id_artists': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'name': 'Popular (with Playboi Carti & Madonna)',
#   'artists': ['The Weeknd', 'Playboi Carti', 'Madonna'],
#   'popularity': 86},
#  {'id': '7MXVkk9YMctZqd1Srtv4MB',
#   'id_artists': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'name': 'Starboy',
#   'artists': ['The Weeknd', 'Daft Punk'],
#   'popularity': 93},
#  {'id': '2LBqCSwhJGcFQeTHMVGwy3',
#   'id_artists': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'name': 'Die For You',
#   'artists': ['The Weeknd'],
#   'popularity': 89},
#  {'id': '52eIcoLUM25zbQupAZYoFh',
#   'id_artists': '1URnnhqYAYcrqrcwql10ft',
#   'name': 'redrum',
#   'artists': ['21 Savage'],
#   'popularity': 96},
#  {'id': '5u6vkDnOyaf8LsteDAj2ub',
#   'id_artists': '1URnnhqYAYcrqrcwql10ft',
#   'name': 'Ghostface Killers (feat. Travis Scott)',
#   'artists': ['21 Savage', 'Offset', 'Metro Boomin', 'Travis Scott'],
#   'popularity': 72},
#  {'id': '6OaVWaGfhXn70ZJfdVcabn',
#   'id_artists': '0Y5tJX1MQlPlqiwlOH1tJY',
#   'name': 'NO BYSTANDERS',
#   'artists': ['Travis Scott'],
#   'popularity': 75},
#  {'id': '1xYpVRspgaLxdJLOTQkTjg',
#   'id_artists': '0Y5tJX1MQlPlqiwlOH1tJY',
#   'name': 'STOP TRYING TO BE GOD',
#   'artists': ['Travis Scott'],
#   'popularity': 71},
#  {'id': '4SZepBIPDRwPaHIjAKwRDb',
#   'id_artists': '0Y5tJX1MQlPlqiwlOH1tJY',
#   'name': 'R.I.P. SCREW',
#   'artists': ['Travis Scott'],
#   'popularity': 69},
#  {'id': '1i9lZvlaDdWDPyXEE95aiq',
#   'id_artists': '0Y5tJX1MQlPlqiwlOH1tJY',
#   'name': 'TELEKINESIS (feat. SZA & Future)',
#   'artists': ['Travis Scott', 'SZA', 'Future'],
#   'popularity': 86},
#  {'id': '6koKhrBBcExADvWuOgceNZ',
#   'id_artists': '7tYKF4w9nC0nq9CsPZTHyP',
#   'name': 'Open Arms (feat. Travis Scott)',
#   'artists': ['SZA', 'Travis Scott'],
#   'popularity': 81},
#  {'id': '6wsqVwoiVH2kde4k4KKAFU',
#   'id_artists': '0Y5tJX1MQlPlqiwlOH1tJY',
#   'name': 'I KNOW ?',
#   'artists': ['Travis Scott'],
#   'popularity': 91},
#  {'id': '5W8YXBz9MTIDyrpYaCg2Ky',
#   'id_artists': '4RddZ3iHvSpGV4dvATac9X',
#   'name': 'Last Resort',
#   'artists': ['Papa Roach'],
#   'popularity': 83},
#  {'id': '5RxCC8ecpIb6W9MVrJNmSF',
#   'id_artists': '4RddZ3iHvSpGV4dvATac9X',
#   'name': '...To Be Loved',
#   'artists': ['Papa Roach'],
#   'popularity': 58},
#  {'id': '3UULkHdmLDqBDPmBYltoRE',
#   'id_artists': '4DWX7u8BV0vZIQSpJQQDWU',
#   'name': 'Metalingus',
#   'artists': ['Alter Bridge'],
#   'popularity': 69},
#  {'id': '2o4AknH1hXnleCRW2rH45w',
#   'id_artists': '4DWX7u8BV0vZIQSpJQQDWU',
#   'name': 'Blackbird',
#   'artists': ['Alter Bridge'],
#   'popularity': 56},
#  {'id': '1fewSx2d5KIZ04wsooEBOz',
#   'id_artists': '0iEtIxbK0KxaSlF7G42ZOp',
#   'name': 'Space Cadet (feat. Gunna)',
#   'artists': ['Metro Boomin', 'Gunna'],
#   'popularity': 83},
#  {'id': '7sO5G9EABYOXQKNPNiE9NR',
#   'id_artists': '4DdkRBBYG6Yk9Ka8tdJ9BW',
#   'name': 'Ric Flair Drip (with Metro Boomin)',
#   'artists': ['Offset', 'Metro Boomin'],
#   'popularity': 85},
#  {'id': '2Hh3ETdQKrmSI3QS0hme7g',
#   'id_artists': '0iEtIxbK0KxaSlF7G42ZOp',
#   'name': 'Too Many Nights (feat. Don Toliver & with Future)',
#   'artists': ['Metro Boomin', 'Future', 'Don Toliver'],
#   'popularity': 88},
#  {'id': '1zi7xx7UVEFkmKfv06H8x0',
#   'id_artists': '3TVXtAsR1Inumwj472S9r4',
#   'name': 'One Dance',
#   'artists': ['Drake', 'Wizkid', 'Kyla'],
#   'popularity': 90},
#  {'id': '28FGV3ORH14MYORd7s5dlU',
#   'id_artists': '7dGJo4pcD2V6oG8kP0tJRR',
#   'name': "Not Alike (feat. Royce Da 5'9)",
#   'artists': ['Eminem', 'Royce Da 5\'9"'],
#   'popularity': 63},
#  {'id': '4xkOaSrkexMciUUogZKVTS',
#   'id_artists': '7dGJo4pcD2V6oG8kP0tJRR',
#   'name': 'Till I Collapse',
#   'artists': ['Eminem', 'Nate Dogg'],
#   'popularity': 86},
#  {'id': '4woTEX1wYOTGDqNXuavlRC',
#   'id_artists': '7dGJo4pcD2V6oG8kP0tJRR',
#   'name': 'Superman',
#   'artists': ['Eminem', 'Dina Rae'],
#   'popularity': 85},
#  {'id': '2nLtzopw4rPReszdYBJU6h',
#   'id_artists': '6XyY86QOPPrYVGvF9ch6wz',
#   'name': 'Numb',
#   'artists': ['Linkin Park'],
#   'popularity': 88},
#  {'id': '0xpDDXbjPStXA8vwfKUWcI',
#   'id_artists': '3q7HBObVc0L8jNeTe5Gofh',
#   'name': "Don't Worry 'Bout It",
#   'artists': ['50 Cent', 'Yo Gotti'],
#   'popularity': 0},
#  {'id': '0nKZeSrqH9u31NLoTUsYBR',
#   'id_artists': '7dGJo4pcD2V6oG8kP0tJRR',
#   'name': "You Don't Know",
#   'artists': ['Eminem', '50 Cent', 'Ca$his', 'Lloyd Banks'],
#   'popularity': 59},
#  {'id': '1IRNjfivqiDhzey02C11ge',
#   'id_artists': '3q7HBObVc0L8jNeTe5Gofh',
#   'name': 'P.I.M.P.',
#   'artists': ['50 Cent'],
#   'popularity': 0},
#  {'id': '52bHOlLu5iZO5huNdVUlue',
#   'id_artists': '6XyY86QOPPrYVGvF9ch6wz',
#   'name': 'High Voltage',
#   'artists': ['Linkin Park'],
#   'popularity': 0},
#  {'id': '47EJbrfrAAg4828kwQDUp2',
#   'id_artists': '7hJcb9fa4alzcOq3EaNPoG',
#   'name': "You Can Put It in a Zag, I'mma Put It in a Blunt",
#   'artists': ['Snoop Dogg', 'Wiz Khalifa'],
#   'popularity': 35},
#  {'id': '0SNeQWVJQYpdLawJV91nGa',
#   'id_artists': '5XQ5Ie0v4Du9jLgY5p1ozb',
#   'name': 'Gang Of Marijuana (feat. Mac Lucci)',
#   'artists': ['James Wade', 'Snoop Dogg'],
#   'popularity': 17},
#  {'id': '0R7YVi7w41Dr9jU5vblAok',
#   'id_artists': '7hJcb9fa4alzcOq3EaNPoG',
#   'name': 'Sweat - Remix',
#   'artists': ['Snoop Dogg', 'David Guetta'],
#   'popularity': 71},
#  {'id': '2RUFzxyUlI36KKy9Agkqze',
#   'id_artists': '5K4W6rqBFWDnAN6FQUkS6x',
#   'name': 'POWER',
#   'artists': ['Kanye West'],
#   'popularity': 0},
#  {'id': '2GtaNlidzvK3hY78kCdsHa',
#   'id_artists': '0fA0VVWsXO9YnASrzqfmYu',
#   'name': 'Marijuana',
#   'artists': ['Kid Cudi'],
#   'popularity': 60},
#  {'id': '2JPavCWYtpCSnyLwnLBvXZ',
#   'id_artists': '13ubrt8QOOCPljQ2FL1Kca',
#   'name': 'Long Live A$AP',
#   'artists': ['A$AP Rocky'],
#   'popularity': 0},
#  {'id': '4go2hxLM6ijk0K76ZY0Nhd',
#   'id_artists': '13ubrt8QOOCPljQ2FL1Kca',
#   'name': 'Goldie',
#   'artists': ['A$AP Rocky'],
#   'popularity': 0},
#  {'id': '3IvVQ1qmekCQ4LRwGCyIJA',
#   'id_artists': '13ubrt8QOOCPljQ2FL1Kca',
#   'name': 'PMW (All I Really Need) (feat. ScHoolboy Q)',
#   'artists': ['A$AP Rocky', 'ScHoolboy Q'],
#   'popularity': 0},
#  {'id': '4XoP1AkbOurU9CeZ2rMEz2',
#   'id_artists': '13ubrt8QOOCPljQ2FL1Kca',
#   'name': "F**kin' Problems (feat. Drake, 2 Chainz & Kendrick Lamar)",
#   'artists': ['A$AP Rocky', 'Drake', '2 Chainz', 'Kendrick Lamar'],
#   'popularity': 0},
#  {'id': '22Mme5vsZ688TMUieIHdx3',
#   'id_artists': '13ubrt8QOOCPljQ2FL1Kca',
#   'name': 'Wild for the Night (feat. Skrillex & Birdy Nam Nam)',
#   'artists': ['A$AP Rocky', 'Skrillex', 'Birdy Nam Nam', 'Lord Flacko'],
#   'popularity': 0},
#  {'id': '40H5libEZWrbkc8HTlXGbt',
#   'id_artists': '13ubrt8QOOCPljQ2FL1Kca',
#   'name': 'Fashion Killa',
#   'artists': ['A$AP Rocky'],
#   'popularity': 0},
#  {'id': '015IsLQFXbEm0f541N2qoX',
#   'id_artists': '2o5jDhtHVPhrJdv3cEQ99Z',
#   'name': 'Red Lights',
#   'artists': ['Tiësto'],
#   'popularity': 0}]

# %%
#Extract the user's favorite song attributes
while saved_tracks['next']:
    saved_tracks = spotify.next(saved_tracks)
    tracks.extend([select_features(track) for track in saved_tracks['items']])

# %%
#Create pandas dataframe
df_tracks = pd.DataFrame(tracks)
pd.set_option('display.max_rows', len(tracks))
df_tracks['artists'] = df_tracks['artists'].apply(lambda artists: artists[0])

# %%
df_tracks.head(10)
# Out:
#                        id              id_artists  \
# 0  56sk7jBpZV0CD31G9hEU3b  2xiIXseIJcq3nG7C8fHeBj
# 1  7piw04hPQZ1OHZ9Fq9JOXR  2xiIXseIJcq3nG7C8fHeBj
# 2  3HE50TVRquwXe9yv2HFoNL  2xiIXseIJcq3nG7C8fHeBj
# 3  0M955bMOoilikPXwKLYpoi  2xiIXseIJcq3nG7C8fHeBj
# 4  1nltpRhEiXikwDlVn4UADk  246dkjvS1zLTtiykXe5h60
# 5  5Ja2u1FPlVxrxeMWEa2dcn  246dkjvS1zLTtiykXe5h60
# 6  1D2L6MefbXon28PzIk9I3r  246dkjvS1zLTtiykXe5h60
# 7  5VuxWXbt7XENQCtE9TzpTv  246dkjvS1zLTtiykXe5h60
# 8  7dt6x5M1jzdTEt8oCbisTK  246dkjvS1zLTtiykXe5h60
# 9  0e7ipj03S05BNilyu5bRzt  246dkjvS1zLTtiykXe5h60
#
#                               name           artists  popularity
# 0             Animal I Have Become  Three Days Grace          77
# 1                    Time of Dying  Three Days Grace          68
# 2                   Never Too Late  Three Days Grace          71
# 3      I Hate Everything About You  Three Days Grace          78
# 4  One Right Now (with The Weeknd)       Post Malone          71
# 5                   When I’m Alone       Post Malone          57
# 6                      92 Explorer       Post Malone          69
# 7  Spoil My Night (feat. Swae Lee)       Post Malone          66
# 8                       Better Now       Post Malone          82
# 9       rockstar (feat. 21 Savage)       Post Malone          84

# %%
#Creating dict for the audio attributes 
audio_features = {}

# %%
#Extract the audio attributes 
for idd in df_tracks['id'].tolist():
    audio_features[idd] = spotify.audio_features(idd)[0]

# %%
audio_features
# Out:
# {'56sk7jBpZV0CD31G9hEU3b': {'danceability': 0.553,
#   'energy': 0.853,
#   'key': 8,
#   'loudness': -3.668,
#   'mode': 1,
#   'speechiness': 0.0339,
#   'acousticness': 0.000684,
#   'instrumentalness': 0,
#   'liveness': 0.126,
#   'valence': 0.506,
#   'tempo': 122.023,
#   'type': 'audio_features',
#   'id': '56sk7jBpZV0CD31G9hEU3b',
#   'uri': 'spotify:track:56sk7jBpZV0CD31G9hEU3b',
#   'track_href': 'https://api.spotify.com/v1/tracks/56sk7jBpZV0CD31G9hEU3b',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/56sk7jBpZV0CD31G9hEU3b',
#   'duration_ms': 231400,
#   'time_signature': 4},
#  '7piw04hPQZ1OHZ9Fq9JOXR': {'danceability': 0.306,
#   'energy': 0.873,
#   'key': 0,
#   'loudness': -3.668,
#   'mode': 0,
#   'speechiness': 0.0567,
#   'acousticness': 0.00105,
#   'instrumentalness': 0,
#   'liveness': 0.52,
#   'valence': 0.452,
#   'tempo': 198.387,
#   'type': 'audio_features',
#   'id': '7piw04hPQZ1OHZ9Fq9JOXR',
#   'uri': 'spotify:track:7piw04hPQZ1OHZ9Fq9JOXR',
#   'track_href': 'https://api.spotify.com/v1/tracks/7piw04hPQZ1OHZ9Fq9JOXR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7piw04hPQZ1OHZ9Fq9JOXR',
#   'duration_ms': 186373,
#   'time_signature': 4},
#  '3HE50TVRquwXe9yv2HFoNL': {'danceability': 0.433,
#   'energy': 0.778,
#   'key': 2,
#   'loudness': -4.68,
#   'mode': 0,
#   'speechiness': 0.0371,
#   'acousticness': 0.00838,
#   'instrumentalness': 0,
#   'liveness': 0.163,
#   'valence': 0.217,
#   'tempo': 149.864,
#   'type': 'audio_features',
#   'id': '3HE50TVRquwXe9yv2HFoNL',
#   'uri': 'spotify:track:3HE50TVRquwXe9yv2HFoNL',
#   'track_href': 'https://api.spotify.com/v1/tracks/3HE50TVRquwXe9yv2HFoNL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3HE50TVRquwXe9yv2HFoNL',
#   'duration_ms': 209333,
#   'time_signature': 4},
#  '0M955bMOoilikPXwKLYpoi': {'danceability': 0.498,
#   'energy': 0.83,
#   'key': 6,
#   'loudness': -5.157,
#   'mode': 0,
#   'speechiness': 0.0421,
#   'acousticness': 0.00461,
#   'instrumentalness': 0,
#   'liveness': 0.139,
#   'valence': 0.453,
#   'tempo': 89.342,
#   'type': 'audio_features',
#   'id': '0M955bMOoilikPXwKLYpoi',
#   'uri': 'spotify:track:0M955bMOoilikPXwKLYpoi',
#   'track_href': 'https://api.spotify.com/v1/tracks/0M955bMOoilikPXwKLYpoi',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0M955bMOoilikPXwKLYpoi',
#   'duration_ms': 231480,
#   'time_signature': 4},
#  '1nltpRhEiXikwDlVn4UADk': {'danceability': 0.682,
#   'energy': 0.764,
#   'key': 1,
#   'loudness': -5.411,
#   'mode': 1,
#   'speechiness': 0.0477,
#   'acousticness': 0.0363,
#   'instrumentalness': 0,
#   'liveness': 0.103,
#   'valence': 0.701,
#   'tempo': 97.023,
#   'type': 'audio_features',
#   'id': '1nltpRhEiXikwDlVn4UADk',
#   'uri': 'spotify:track:1nltpRhEiXikwDlVn4UADk',
#   'track_href': 'https://api.spotify.com/v1/tracks/1nltpRhEiXikwDlVn4UADk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1nltpRhEiXikwDlVn4UADk',
#   'duration_ms': 192721,
#   'time_signature': 4},
#  '5Ja2u1FPlVxrxeMWEa2dcn': {'danceability': 0.485,
#   'energy': 0.656,
#   'key': 10,
#   'loudness': -6.121,
#   'mode': 0,
#   'speechiness': 0.0528,
#   'acousticness': 0.0346,
#   'instrumentalness': 0,
#   'liveness': 0.155,
#   'valence': 0.106,
#   'tempo': 140.107,
#   'type': 'audio_features',
#   'id': '5Ja2u1FPlVxrxeMWEa2dcn',
#   'uri': 'spotify:track:5Ja2u1FPlVxrxeMWEa2dcn',
#   'track_href': 'https://api.spotify.com/v1/tracks/5Ja2u1FPlVxrxeMWEa2dcn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Ja2u1FPlVxrxeMWEa2dcn',
#   'duration_ms': 195111,
#   'time_signature': 4},
#  '1D2L6MefbXon28PzIk9I3r': {'danceability': 0.798,
#   'energy': 0.733,
#   'key': 7,
#   'loudness': -4.811,
#   'mode': 0,
#   'speechiness': 0.0476,
#   'acousticness': 0.265,
#   'instrumentalness': 1.25e-06,
#   'liveness': 0.114,
#   'valence': 0.861,
#   'tempo': 146.046,
#   'type': 'audio_features',
#   'id': '1D2L6MefbXon28PzIk9I3r',
#   'uri': 'spotify:track:1D2L6MefbXon28PzIk9I3r',
#   'track_href': 'https://api.spotify.com/v1/tracks/1D2L6MefbXon28PzIk9I3r',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1D2L6MefbXon28PzIk9I3r',
#   'duration_ms': 211427,
#   'time_signature': 4},
#  '5VuxWXbt7XENQCtE9TzpTv': {'danceability': 0.672,
#   'energy': 0.717,
#   'key': 1,
#   'loudness': -2.714,
#   'mode': 1,
#   'speechiness': 0.034,
#   'acousticness': 0.341,
#   'instrumentalness': 2.4e-05,
#   'liveness': 0.106,
#   'valence': 0.225,
#   'tempo': 160.981,
#   'type': 'audio_features',
#   'id': '5VuxWXbt7XENQCtE9TzpTv',
#   'uri': 'spotify:track:5VuxWXbt7XENQCtE9TzpTv',
#   'track_href': 'https://api.spotify.com/v1/tracks/5VuxWXbt7XENQCtE9TzpTv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5VuxWXbt7XENQCtE9TzpTv',
#   'duration_ms': 194560,
#   'time_signature': 4},
#  '7dt6x5M1jzdTEt8oCbisTK': {'danceability': 0.68,
#   'energy': 0.578,
#   'key': 10,
#   'loudness': -5.804,
#   'mode': 1,
#   'speechiness': 0.04,
#   'acousticness': 0.331,
#   'instrumentalness': 0,
#   'liveness': 0.135,
#   'valence': 0.341,
#   'tempo': 145.038,
#   'type': 'audio_features',
#   'id': '7dt6x5M1jzdTEt8oCbisTK',
#   'uri': 'spotify:track:7dt6x5M1jzdTEt8oCbisTK',
#   'track_href': 'https://api.spotify.com/v1/tracks/7dt6x5M1jzdTEt8oCbisTK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7dt6x5M1jzdTEt8oCbisTK',
#   'duration_ms': 231267,
#   'time_signature': 4},
#  '0e7ipj03S05BNilyu5bRzt': {'danceability': 0.585,
#   'energy': 0.52,
#   'key': 5,
#   'loudness': -6.136,
#   'mode': 0,
#   'speechiness': 0.0712,
#   'acousticness': 0.124,
#   'instrumentalness': 7.01e-05,
#   'liveness': 0.131,
#   'valence': 0.129,
#   'tempo': 159.801,
#   'type': 'audio_features',
#   'id': '0e7ipj03S05BNilyu5bRzt',
#   'uri': 'spotify:track:0e7ipj03S05BNilyu5bRzt',
#   'track_href': 'https://api.spotify.com/v1/tracks/0e7ipj03S05BNilyu5bRzt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0e7ipj03S05BNilyu5bRzt',
#   'duration_ms': 218147,
#   'time_signature': 4},
#  '5QO79kh1waicV47BqGRL3g': {'danceability': 0.68,
#   'energy': 0.826,
#   'key': 0,
#   'loudness': -5.487,
#   'mode': 1,
#   'speechiness': 0.0309,
#   'acousticness': 0.0212,
#   'instrumentalness': 1.24e-05,
#   'liveness': 0.543,
#   'valence': 0.644,
#   'tempo': 118.051,
#   'type': 'audio_features',
#   'id': '5QO79kh1waicV47BqGRL3g',
#   'uri': 'spotify:track:5QO79kh1waicV47BqGRL3g',
#   'track_href': 'https://api.spotify.com/v1/tracks/5QO79kh1waicV47BqGRL3g',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5QO79kh1waicV47BqGRL3g',
#   'duration_ms': 215627,
#   'time_signature': 4},
#  '7GUhiAHLoVy1V8ucQuZ3CB': {'danceability': 0.854,
#   'energy': 0.668,
#   'key': 1,
#   'loudness': -6.243,
#   'mode': 1,
#   'speechiness': 0.2,
#   'acousticness': 0.0604,
#   'instrumentalness': 8.39e-05,
#   'liveness': 0.382,
#   'valence': 0.833,
#   'tempo': 99.018,
#   'type': 'audio_features',
#   'id': '7GUhiAHLoVy1V8ucQuZ3CB',
#   'uri': 'spotify:track:7GUhiAHLoVy1V8ucQuZ3CB',
#   'track_href': 'https://api.spotify.com/v1/tracks/7GUhiAHLoVy1V8ucQuZ3CB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7GUhiAHLoVy1V8ucQuZ3CB',
#   'duration_ms': 215467,
#   'time_signature': 4},
#  '7MXVkk9YMctZqd1Srtv4MB': {'danceability': 0.679,
#   'energy': 0.587,
#   'key': 7,
#   'loudness': -7.015,
#   'mode': 1,
#   'speechiness': 0.276,
#   'acousticness': 0.141,
#   'instrumentalness': 6.35e-06,
#   'liveness': 0.137,
#   'valence': 0.486,
#   'tempo': 186.003,
#   'type': 'audio_features',
#   'id': '7MXVkk9YMctZqd1Srtv4MB',
#   'uri': 'spotify:track:7MXVkk9YMctZqd1Srtv4MB',
#   'track_href': 'https://api.spotify.com/v1/tracks/7MXVkk9YMctZqd1Srtv4MB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7MXVkk9YMctZqd1Srtv4MB',
#   'duration_ms': 230453,
#   'time_signature': 4},
#  '2LBqCSwhJGcFQeTHMVGwy3': {'danceability': 0.586,
#   'energy': 0.525,
#   'key': 1,
#   'loudness': -7.163,
#   'mode': 0,
#   'speechiness': 0.0615,
#   'acousticness': 0.111,
#   'instrumentalness': 0,
#   'liveness': 0.134,
#   'valence': 0.508,
#   'tempo': 133.629,
#   'type': 'audio_features',
#   'id': '2LBqCSwhJGcFQeTHMVGwy3',
#   'uri': 'spotify:track:2LBqCSwhJGcFQeTHMVGwy3',
#   'track_href': 'https://api.spotify.com/v1/tracks/2LBqCSwhJGcFQeTHMVGwy3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2LBqCSwhJGcFQeTHMVGwy3',
#   'duration_ms': 260253,
#   'time_signature': 4},
#  '52eIcoLUM25zbQupAZYoFh': {'danceability': 0.624,
#   'energy': 0.74,
#   'key': 2,
#   'loudness': -8.445,
#   'mode': 1,
#   'speechiness': 0.0481,
#   'acousticness': 0.00529,
#   'instrumentalness': 0.000224,
#   'liveness': 0.5,
#   'valence': 0.246,
#   'tempo': 172.089,
#   'type': 'audio_features',
#   'id': '52eIcoLUM25zbQupAZYoFh',
#   'uri': 'spotify:track:52eIcoLUM25zbQupAZYoFh',
#   'track_href': 'https://api.spotify.com/v1/tracks/52eIcoLUM25zbQupAZYoFh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/52eIcoLUM25zbQupAZYoFh',
#   'duration_ms': 270698,
#   'time_signature': 4},
#  '5u6vkDnOyaf8LsteDAj2ub': {'danceability': 0.782,
#   'energy': 0.435,
#   'key': 2,
#   'loudness': -7.033,
#   'mode': 1,
#   'speechiness': 0.156,
#   'acousticness': 0.333,
#   'instrumentalness': 1.31e-05,
#   'liveness': 0.342,
#   'valence': 0.242,
#   'tempo': 82.996,
#   'type': 'audio_features',
#   'id': '5u6vkDnOyaf8LsteDAj2ub',
#   'uri': 'spotify:track:5u6vkDnOyaf8LsteDAj2ub',
#   'track_href': 'https://api.spotify.com/v1/tracks/5u6vkDnOyaf8LsteDAj2ub',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5u6vkDnOyaf8LsteDAj2ub',
#   'duration_ms': 268933,
#   'time_signature': 4},
#  '6OaVWaGfhXn70ZJfdVcabn': {'danceability': 0.731,
#   'energy': 0.811,
#   'key': 1,
#   'loudness': -3.225,
#   'mode': 1,
#   'speechiness': 0.0712,
#   'acousticness': 0.0204,
#   'instrumentalness': 0,
#   'liveness': 0.411,
#   'valence': 0.426,
#   'tempo': 147.045,
#   'type': 'audio_features',
#   'id': '6OaVWaGfhXn70ZJfdVcabn',
#   'uri': 'spotify:track:6OaVWaGfhXn70ZJfdVcabn',
#   'track_href': 'https://api.spotify.com/v1/tracks/6OaVWaGfhXn70ZJfdVcabn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6OaVWaGfhXn70ZJfdVcabn',
#   'duration_ms': 218284,
#   'time_signature': 4},
#  '1xYpVRspgaLxdJLOTQkTjg': {'danceability': 0.588,
#   'energy': 0.567,
#   'key': 4,
#   'loudness': -3.738,
#   'mode': 0,
#   'speechiness': 0.0628,
#   'acousticness': 0.221,
#   'instrumentalness': 0,
#   'liveness': 0.135,
#   'valence': 0.113,
#   'tempo': 150.009,
#   'type': 'audio_features',
#   'id': '1xYpVRspgaLxdJLOTQkTjg',
#   'uri': 'spotify:track:1xYpVRspgaLxdJLOTQkTjg',
#   'track_href': 'https://api.spotify.com/v1/tracks/1xYpVRspgaLxdJLOTQkTjg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1xYpVRspgaLxdJLOTQkTjg',
#   'duration_ms': 338438,
#   'time_signature': 4},
#  '4SZepBIPDRwPaHIjAKwRDb': {'danceability': 0.607,
#   'energy': 0.609,
#   'key': 0,
#   'loudness': -5.978,
#   'mode': 0,
#   'speechiness': 0.291,
#   'acousticness': 0.389,
#   'instrumentalness': 1.6e-05,
#   'liveness': 0.111,
#   'valence': 0.556,
#   'tempo': 74.946,
#   'type': 'audio_features',
#   'id': '4SZepBIPDRwPaHIjAKwRDb',
#   'uri': 'spotify:track:4SZepBIPDRwPaHIjAKwRDb',
#   'track_href': 'https://api.spotify.com/v1/tracks/4SZepBIPDRwPaHIjAKwRDb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4SZepBIPDRwPaHIjAKwRDb',
#   'duration_ms': 185610,
#   'time_signature': 4},
#  '1i9lZvlaDdWDPyXEE95aiq': {'danceability': 0.458,
#   'energy': 0.535,
#   'key': 5,
#   'loudness': -4.854,
#   'mode': 0,
#   'speechiness': 0.0281,
#   'acousticness': 0.575,
#   'instrumentalness': 0,
#   'liveness': 0.168,
#   'valence': 0.216,
#   'tempo': 82.826,
#   'type': 'audio_features',
#   'id': '1i9lZvlaDdWDPyXEE95aiq',
#   'uri': 'spotify:track:1i9lZvlaDdWDPyXEE95aiq',
#   'track_href': 'https://api.spotify.com/v1/tracks/1i9lZvlaDdWDPyXEE95aiq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1i9lZvlaDdWDPyXEE95aiq',
#   'duration_ms': 353755,
#   'time_signature': 4},
#  '6koKhrBBcExADvWuOgceNZ': {'danceability': 0.434,
#   'energy': 0.586,
#   'key': 9,
#   'loudness': -7.612,
#   'mode': 1,
#   'speechiness': 0.138,
#   'acousticness': 0.753,
#   'instrumentalness': 0.0144,
#   'liveness': 0.146,
#   'valence': 0.239,
#   'tempo': 78.259,
#   'type': 'audio_features',
#   'id': '6koKhrBBcExADvWuOgceNZ',
#   'uri': 'spotify:track:6koKhrBBcExADvWuOgceNZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6koKhrBBcExADvWuOgceNZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6koKhrBBcExADvWuOgceNZ',
#   'duration_ms': 239613,
#   'time_signature': 4},
#  '6wsqVwoiVH2kde4k4KKAFU': {'danceability': 0.927,
#   'energy': 0.619,
#   'key': 5,
#   'loudness': -4.441,
#   'mode': 0,
#   'speechiness': 0.0539,
#   'acousticness': 0.0186,
#   'instrumentalness': 0,
#   'liveness': 0.104,
#   'valence': 0.817,
#   'tempo': 117.995,
#   'type': 'audio_features',
#   'id': '6wsqVwoiVH2kde4k4KKAFU',
#   'uri': 'spotify:track:6wsqVwoiVH2kde4k4KKAFU',
#   'track_href': 'https://api.spotify.com/v1/tracks/6wsqVwoiVH2kde4k4KKAFU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6wsqVwoiVH2kde4k4KKAFU',
#   'duration_ms': 211582,
#   'time_signature': 4},
#  '5W8YXBz9MTIDyrpYaCg2Ky': {'danceability': 0.589,
#   'energy': 0.89,
#   'key': 4,
#   'loudness': -3.719,
#   'mode': 0,
#   'speechiness': 0.0603,
#   'acousticness': 0.000481,
#   'instrumentalness': 0.00082,
#   'liveness': 0.201,
#   'valence': 0.692,
#   'tempo': 90.598,
#   'type': 'audio_features',
#   'id': '5W8YXBz9MTIDyrpYaCg2Ky',
#   'uri': 'spotify:track:5W8YXBz9MTIDyrpYaCg2Ky',
#   'track_href': 'https://api.spotify.com/v1/tracks/5W8YXBz9MTIDyrpYaCg2Ky',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5W8YXBz9MTIDyrpYaCg2Ky',
#   'duration_ms': 199907,
#   'time_signature': 4},
#  '5RxCC8ecpIb6W9MVrJNmSF': {'danceability': 0.478,
#   'energy': 0.977,
#   'key': 8,
#   'loudness': -3.162,
#   'mode': 1,
#   'speechiness': 0.0751,
#   'acousticness': 0.00473,
#   'instrumentalness': 0,
#   'liveness': 0.509,
#   'valence': 0.482,
#   'tempo': 96.047,
#   'type': 'audio_features',
#   'id': '5RxCC8ecpIb6W9MVrJNmSF',
#   'uri': 'spotify:track:5RxCC8ecpIb6W9MVrJNmSF',
#   'track_href': 'https://api.spotify.com/v1/tracks/5RxCC8ecpIb6W9MVrJNmSF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5RxCC8ecpIb6W9MVrJNmSF',
#   'duration_ms': 182120,
#   'time_signature': 4},
#  '3UULkHdmLDqBDPmBYltoRE': {'danceability': 0.496,
#   'energy': 0.981,
#   'key': 8,
#   'loudness': -3.268,
#   'mode': 1,
#   'speechiness': 0.108,
#   'acousticness': 9.33e-06,
#   'instrumentalness': 0,
#   'liveness': 0.0958,
#   'valence': 0.163,
#   'tempo': 109.905,
#   'type': 'audio_features',
#   'id': '3UULkHdmLDqBDPmBYltoRE',
#   'uri': 'spotify:track:3UULkHdmLDqBDPmBYltoRE',
#   'track_href': 'https://api.spotify.com/v1/tracks/3UULkHdmLDqBDPmBYltoRE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3UULkHdmLDqBDPmBYltoRE',
#   'duration_ms': 259960,
#   'time_signature': 4},
#  '2o4AknH1hXnleCRW2rH45w': {'danceability': 0.279,
#   'energy': 0.806,
#   'key': 6,
#   'loudness': -4.714,
#   'mode': 0,
#   'speechiness': 0.0448,
#   'acousticness': 0.00499,
#   'instrumentalness': 0.0126,
#   'liveness': 0.116,
#   'valence': 0.132,
#   'tempo': 149.463,
#   'type': 'audio_features',
#   'id': '2o4AknH1hXnleCRW2rH45w',
#   'uri': 'spotify:track:2o4AknH1hXnleCRW2rH45w',
#   'track_href': 'https://api.spotify.com/v1/tracks/2o4AknH1hXnleCRW2rH45w',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2o4AknH1hXnleCRW2rH45w',
#   'duration_ms': 478133,
#   'time_signature': 3},
#  '1fewSx2d5KIZ04wsooEBOz': {'danceability': 0.901,
#   'energy': 0.464,
#   'key': 5,
#   'loudness': -9.789,
#   'mode': 0,
#   'speechiness': 0.0645,
#   'acousticness': 0.368,
#   'instrumentalness': 1.71e-05,
#   'liveness': 0.238,
#   'valence': 0.638,
#   'tempo': 109.004,
#   'type': 'audio_features',
#   'id': '1fewSx2d5KIZ04wsooEBOz',
#   'uri': 'spotify:track:1fewSx2d5KIZ04wsooEBOz',
#   'track_href': 'https://api.spotify.com/v1/tracks/1fewSx2d5KIZ04wsooEBOz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1fewSx2d5KIZ04wsooEBOz',
#   'duration_ms': 203267,
#   'time_signature': 4},
#  '7sO5G9EABYOXQKNPNiE9NR': {'danceability': 0.88,
#   'energy': 0.428,
#   'key': 9,
#   'loudness': -8.28,
#   'mode': 1,
#   'speechiness': 0.206,
#   'acousticness': 0.149,
#   'instrumentalness': 5.05e-05,
#   'liveness': 0.114,
#   'valence': 0.333,
#   'tempo': 100.007,
#   'type': 'audio_features',
#   'id': '7sO5G9EABYOXQKNPNiE9NR',
#   'uri': 'spotify:track:7sO5G9EABYOXQKNPNiE9NR',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sO5G9EABYOXQKNPNiE9NR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sO5G9EABYOXQKNPNiE9NR',
#   'duration_ms': 172800,
#   'time_signature': 4},
#  '2Hh3ETdQKrmSI3QS0hme7g': {'danceability': 0.684,
#   'energy': 0.671,
#   'key': 7,
#   'loudness': -4.392,
#   'mode': 0,
#   'speechiness': 0.0464,
#   'acousticness': 0.189,
#   'instrumentalness': 2.37e-05,
#   'liveness': 0.122,
#   'valence': 0.156,
#   'tempo': 88.048,
#   'type': 'audio_features',
#   'id': '2Hh3ETdQKrmSI3QS0hme7g',
#   'uri': 'spotify:track:2Hh3ETdQKrmSI3QS0hme7g',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Hh3ETdQKrmSI3QS0hme7g',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Hh3ETdQKrmSI3QS0hme7g',
#   'duration_ms': 199920,
#   'time_signature': 4},
#  '1zi7xx7UVEFkmKfv06H8x0': {'danceability': 0.792,
#   'energy': 0.625,
#   'key': 1,
#   'loudness': -5.609,
#   'mode': 1,
#   'speechiness': 0.0536,
#   'acousticness': 0.00776,
#   'instrumentalness': 0.0018,
#   'liveness': 0.329,
#   'valence': 0.37,
#   'tempo': 103.967,
#   'type': 'audio_features',
#   'id': '1zi7xx7UVEFkmKfv06H8x0',
#   'uri': 'spotify:track:1zi7xx7UVEFkmKfv06H8x0',
#   'track_href': 'https://api.spotify.com/v1/tracks/1zi7xx7UVEFkmKfv06H8x0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1zi7xx7UVEFkmKfv06H8x0',
#   'duration_ms': 173987,
#   'time_signature': 4},
#  '28FGV3ORH14MYORd7s5dlU': {'danceability': 0.904,
#   'energy': 0.756,
#   'key': 10,
#   'loudness': -3.746,
#   'mode': 1,
#   'speechiness': 0.32,
#   'acousticness': 0.0692,
#   'instrumentalness': 0,
#   'liveness': 0.339,
#   'valence': 0.342,
#   'tempo': 140.005,
#   'type': 'audio_features',
#   'id': '28FGV3ORH14MYORd7s5dlU',
#   'uri': 'spotify:track:28FGV3ORH14MYORd7s5dlU',
#   'track_href': 'https://api.spotify.com/v1/tracks/28FGV3ORH14MYORd7s5dlU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/28FGV3ORH14MYORd7s5dlU',
#   'duration_ms': 288087,
#   'time_signature': 4},
#  '4xkOaSrkexMciUUogZKVTS': {'danceability': 0.548,
#   'energy': 0.847,
#   'key': 1,
#   'loudness': -3.237,
#   'mode': 1,
#   'speechiness': 0.186,
#   'acousticness': 0.0622,
#   'instrumentalness': 0,
#   'liveness': 0.0816,
#   'valence': 0.1,
#   'tempo': 171.447,
#   'type': 'audio_features',
#   'id': '4xkOaSrkexMciUUogZKVTS',
#   'uri': 'spotify:track:4xkOaSrkexMciUUogZKVTS',
#   'track_href': 'https://api.spotify.com/v1/tracks/4xkOaSrkexMciUUogZKVTS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4xkOaSrkexMciUUogZKVTS',
#   'duration_ms': 297787,
#   'time_signature': 4},
#  '4woTEX1wYOTGDqNXuavlRC': {'danceability': 0.802,
#   'energy': 0.755,
#   'key': 4,
#   'loudness': -3.138,
#   'mode': 0,
#   'speechiness': 0.0564,
#   'acousticness': 0.0215,
#   'instrumentalness': 0,
#   'liveness': 0.295,
#   'valence': 0.58,
#   'tempo': 130.027,
#   'type': 'audio_features',
#   'id': '4woTEX1wYOTGDqNXuavlRC',
#   'uri': 'spotify:track:4woTEX1wYOTGDqNXuavlRC',
#   'track_href': 'https://api.spotify.com/v1/tracks/4woTEX1wYOTGDqNXuavlRC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4woTEX1wYOTGDqNXuavlRC',
#   'duration_ms': 350320,
#   'time_signature': 4},
#  '2nLtzopw4rPReszdYBJU6h': {'danceability': 0.496,
#   'energy': 0.863,
#   'key': 9,
#   'loudness': -4.153,
#   'mode': 1,
#   'speechiness': 0.0381,
#   'acousticness': 0.0046,
#   'instrumentalness': 0,
#   'liveness': 0.639,
#   'valence': 0.243,
#   'tempo': 110.018,
#   'type': 'audio_features',
#   'id': '2nLtzopw4rPReszdYBJU6h',
#   'uri': 'spotify:track:2nLtzopw4rPReszdYBJU6h',
#   'track_href': 'https://api.spotify.com/v1/tracks/2nLtzopw4rPReszdYBJU6h',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2nLtzopw4rPReszdYBJU6h',
#   'duration_ms': 185587,
#   'time_signature': 4},
#  '0xpDDXbjPStXA8vwfKUWcI': {'danceability': 0.796,
#   'energy': 0.692,
#   'key': 5,
#   'loudness': -6.001,
#   'mode': 0,
#   'speechiness': 0.279,
#   'acousticness': 0.56,
#   'instrumentalness': 0,
#   'liveness': 0.155,
#   'valence': 0.965,
#   'tempo': 151.093,
#   'type': 'audio_features',
#   'id': '0xpDDXbjPStXA8vwfKUWcI',
#   'uri': 'spotify:track:0xpDDXbjPStXA8vwfKUWcI',
#   'track_href': 'https://api.spotify.com/v1/tracks/0xpDDXbjPStXA8vwfKUWcI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0xpDDXbjPStXA8vwfKUWcI',
#   'duration_ms': 241505,
#   'time_signature': 4},
#  '0nKZeSrqH9u31NLoTUsYBR': {'danceability': 0.767,
#   'energy': 0.864,
#   'key': 10,
#   'loudness': -1.847,
#   'mode': 0,
#   'speechiness': 0.133,
#   'acousticness': 0.0116,
#   'instrumentalness': 0,
#   'liveness': 0.0957,
#   'valence': 0.747,
#   'tempo': 85.475,
#   'type': 'audio_features',
#   'id': '0nKZeSrqH9u31NLoTUsYBR',
#   'uri': 'spotify:track:0nKZeSrqH9u31NLoTUsYBR',
#   'track_href': 'https://api.spotify.com/v1/tracks/0nKZeSrqH9u31NLoTUsYBR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0nKZeSrqH9u31NLoTUsYBR',
#   'duration_ms': 257907,
#   'time_signature': 4},
#  '1IRNjfivqiDhzey02C11ge': {'danceability': 0.684,
#   'energy': 0.773,
#   'key': 10,
#   'loudness': -3.05,
#   'mode': 0,
#   'speechiness': 0.351,
#   'acousticness': 0.0521,
#   'instrumentalness': 1.49e-05,
#   'liveness': 0.0328,
#   'valence': 0.873,
#   'tempo': 78.66,
#   'type': 'audio_features',
#   'id': '1IRNjfivqiDhzey02C11ge',
#   'uri': 'spotify:track:1IRNjfivqiDhzey02C11ge',
#   'track_href': 'https://api.spotify.com/v1/tracks/1IRNjfivqiDhzey02C11ge',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1IRNjfivqiDhzey02C11ge',
#   'duration_ms': 249840,
#   'time_signature': 4},
#  '52bHOlLu5iZO5huNdVUlue': {'danceability': 0.594,
#   'energy': 0.969,
#   'key': 7,
#   'loudness': -4.201,
#   'mode': 0,
#   'speechiness': 0.182,
#   'acousticness': 0.1,
#   'instrumentalness': 3e-06,
#   'liveness': 0.274,
#   'valence': 0.267,
#   'tempo': 94.003,
#   'type': 'audio_features',
#   'id': '52bHOlLu5iZO5huNdVUlue',
#   'uri': 'spotify:track:52bHOlLu5iZO5huNdVUlue',
#   'track_href': 'https://api.spotify.com/v1/tracks/52bHOlLu5iZO5huNdVUlue',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/52bHOlLu5iZO5huNdVUlue',
#   'duration_ms': 225027,
#   'time_signature': 4},
#  '47EJbrfrAAg4828kwQDUp2': {'danceability': 0.646,
#   'energy': 0.583,
#   'key': 8,
#   'loudness': -8.604,
#   'mode': 0,
#   'speechiness': 0.307,
#   'acousticness': 0.103,
#   'instrumentalness': 0,
#   'liveness': 0.153,
#   'valence': 0.519,
#   'tempo': 93.94,
#   'type': 'audio_features',
#   'id': '47EJbrfrAAg4828kwQDUp2',
#   'uri': 'spotify:track:47EJbrfrAAg4828kwQDUp2',
#   'track_href': 'https://api.spotify.com/v1/tracks/47EJbrfrAAg4828kwQDUp2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/47EJbrfrAAg4828kwQDUp2',
#   'duration_ms': 199467,
#   'time_signature': 4},
#  '0SNeQWVJQYpdLawJV91nGa': {'danceability': 0.599,
#   'energy': 0.306,
#   'key': 1,
#   'loudness': -16.517,
#   'mode': 1,
#   'speechiness': 0.422,
#   'acousticness': 0.674,
#   'instrumentalness': 0,
#   'liveness': 0.0856,
#   'valence': 0.223,
#   'tempo': 67.389,
#   'type': 'audio_features',
#   'id': '0SNeQWVJQYpdLawJV91nGa',
#   'uri': 'spotify:track:0SNeQWVJQYpdLawJV91nGa',
#   'track_href': 'https://api.spotify.com/v1/tracks/0SNeQWVJQYpdLawJV91nGa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0SNeQWVJQYpdLawJV91nGa',
#   'duration_ms': 294691,
#   'time_signature': 3},
#  '0R7YVi7w41Dr9jU5vblAok': {'danceability': 0.813,
#   'energy': 0.732,
#   'key': 7,
#   'loudness': -5.636,
#   'mode': 1,
#   'speechiness': 0.03,
#   'acousticness': 0.0597,
#   'instrumentalness': 0.00137,
#   'liveness': 0.0826,
#   'valence': 0.731,
#   'tempo': 130.02,
#   'type': 'audio_features',
#   'id': '0R7YVi7w41Dr9jU5vblAok',
#   'uri': 'spotify:track:0R7YVi7w41Dr9jU5vblAok',
#   'track_href': 'https://api.spotify.com/v1/tracks/0R7YVi7w41Dr9jU5vblAok',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0R7YVi7w41Dr9jU5vblAok',
#   'duration_ms': 195987,
#   'time_signature': 4},
#  '2RUFzxyUlI36KKy9Agkqze': {'danceability': 0.539,
#   'energy': 0.907,
#   'key': 0,
#   'loudness': -4.757,
#   'mode': 0,
#   'speechiness': 0.13,
#   'acousticness': 0.0193,
#   'instrumentalness': 0,
#   'liveness': 0.825,
#   'valence': 0.553,
#   'tempo': 154.0,
#   'type': 'audio_features',
#   'id': '2RUFzxyUlI36KKy9Agkqze',
#   'uri': 'spotify:track:2RUFzxyUlI36KKy9Agkqze',
#   'track_href': 'https://api.spotify.com/v1/tracks/2RUFzxyUlI36KKy9Agkqze',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2RUFzxyUlI36KKy9Agkqze',
#   'duration_ms': 292093,
#   'time_signature': 4},
#  '2GtaNlidzvK3hY78kCdsHa': {'danceability': 0.673,
#   'energy': 0.403,
#   'key': 8,
#   'loudness': -9.809,
#   'mode': 0,
#   'speechiness': 0.0273,
#   'acousticness': 0.829,
#   'instrumentalness': 0.829,
#   'liveness': 0.272,
#   'valence': 0.54,
#   'tempo': 140.986,
#   'type': 'audio_features',
#   'id': '2GtaNlidzvK3hY78kCdsHa',
#   'uri': 'spotify:track:2GtaNlidzvK3hY78kCdsHa',
#   'track_href': 'https://api.spotify.com/v1/tracks/2GtaNlidzvK3hY78kCdsHa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2GtaNlidzvK3hY78kCdsHa',
#   'duration_ms': 260200,
#   'time_signature': 4},
#  '2JPavCWYtpCSnyLwnLBvXZ': {'danceability': 0.716,
#   'energy': 0.832,
#   'key': 0,
#   'loudness': -4.939,
#   'mode': 0,
#   'speechiness': 0.351,
#   'acousticness': 0.61,
#   'instrumentalness': 0,
#   'liveness': 0.115,
#   'valence': 0.399,
#   'tempo': 130.042,
#   'type': 'audio_features',
#   'id': '2JPavCWYtpCSnyLwnLBvXZ',
#   'uri': 'spotify:track:2JPavCWYtpCSnyLwnLBvXZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/2JPavCWYtpCSnyLwnLBvXZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2JPavCWYtpCSnyLwnLBvXZ',
#   'duration_ms': 289587,
#   'time_signature': 4},
#  '4go2hxLM6ijk0K76ZY0Nhd': {'danceability': 0.68,
#   'energy': 0.843,
#   'key': 1,
#   'loudness': -4.919,
#   'mode': 1,
#   'speechiness': 0.241,
#   'acousticness': 0.22,
#   'instrumentalness': 3.02e-05,
#   'liveness': 0.378,
#   'valence': 0.743,
#   'tempo': 81.958,
#   'type': 'audio_features',
#   'id': '4go2hxLM6ijk0K76ZY0Nhd',
#   'uri': 'spotify:track:4go2hxLM6ijk0K76ZY0Nhd',
#   'track_href': 'https://api.spotify.com/v1/tracks/4go2hxLM6ijk0K76ZY0Nhd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4go2hxLM6ijk0K76ZY0Nhd',
#   'duration_ms': 192067,
#   'time_signature': 4},
#  '3IvVQ1qmekCQ4LRwGCyIJA': {'danceability': 0.697,
#   'energy': 0.752,
#   'key': 1,
#   'loudness': -4.552,
#   'mode': 1,
#   'speechiness': 0.0526,
#   'acousticness': 0.000367,
#   'instrumentalness': 0,
#   'liveness': 0.32,
#   'valence': 0.269,
#   'tempo': 130.022,
#   'type': 'audio_features',
#   'id': '3IvVQ1qmekCQ4LRwGCyIJA',
#   'uri': 'spotify:track:3IvVQ1qmekCQ4LRwGCyIJA',
#   'track_href': 'https://api.spotify.com/v1/tracks/3IvVQ1qmekCQ4LRwGCyIJA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3IvVQ1qmekCQ4LRwGCyIJA',
#   'duration_ms': 234773,
#   'time_signature': 4},
#  '4XoP1AkbOurU9CeZ2rMEz2': {'danceability': 0.869,
#   'energy': 0.687,
#   'key': 1,
#   'loudness': -6.816,
#   'mode': 1,
#   'speechiness': 0.263,
#   'acousticness': 0.0208,
#   'instrumentalness': 1e-06,
#   'liveness': 0.114,
#   'valence': 0.668,
#   'tempo': 96.006,
#   'type': 'audio_features',
#   'id': '4XoP1AkbOurU9CeZ2rMEz2',
#   'uri': 'spotify:track:4XoP1AkbOurU9CeZ2rMEz2',
#   'track_href': 'https://api.spotify.com/v1/tracks/4XoP1AkbOurU9CeZ2rMEz2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4XoP1AkbOurU9CeZ2rMEz2',
#   'duration_ms': 233787,
#   'time_signature': 4},
#  '22Mme5vsZ688TMUieIHdx3': {'danceability': 0.756,
#   'energy': 0.857,
#   'key': 2,
#   'loudness': -4.185,
#   'mode': 1,
#   'speechiness': 0.336,
#   'acousticness': 0.0452,
#   'instrumentalness': 0,
#   'liveness': 0.121,
#   'valence': 0.688,
#   'tempo': 140.017,
#   'type': 'audio_features',
#   'id': '22Mme5vsZ688TMUieIHdx3',
#   'uri': 'spotify:track:22Mme5vsZ688TMUieIHdx3',
#   'track_href': 'https://api.spotify.com/v1/tracks/22Mme5vsZ688TMUieIHdx3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/22Mme5vsZ688TMUieIHdx3',
#   'duration_ms': 212640,
#   'time_signature': 4},
#  '40H5libEZWrbkc8HTlXGbt': {'danceability': 0.794,
#   'energy': 0.82,
#   'key': 11,
#   'loudness': -5.214,
#   'mode': 1,
#   'speechiness': 0.152,
#   'acousticness': 0.315,
#   'instrumentalness': 0,
#   'liveness': 0.531,
#   'valence': 0.793,
#   'tempo': 140.042,
#   'type': 'audio_features',
#   'id': '40H5libEZWrbkc8HTlXGbt',
#   'uri': 'spotify:track:40H5libEZWrbkc8HTlXGbt',
#   'track_href': 'https://api.spotify.com/v1/tracks/40H5libEZWrbkc8HTlXGbt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/40H5libEZWrbkc8HTlXGbt',
#   'duration_ms': 236280,
#   'time_signature': 4},
#  '015IsLQFXbEm0f541N2qoX': {'danceability': 0.654,
#   'energy': 0.83,
#   'key': 10,
#   'loudness': -4.801,
#   'mode': 1,
#   'speechiness': 0.0366,
#   'acousticness': 0.000629,
#   'instrumentalness': 1.13e-06,
#   'liveness': 0.121,
#   'valence': 0.548,
#   'tempo': 124.989,
#   'type': 'audio_features',
#   'id': '015IsLQFXbEm0f541N2qoX',
#   'uri': 'spotify:track:015IsLQFXbEm0f541N2qoX',
#   'track_href': 'https://api.spotify.com/v1/tracks/015IsLQFXbEm0f541N2qoX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/015IsLQFXbEm0f541N2qoX',
#   'duration_ms': 262200,
#   'time_signature': 4}}

# %%
#Creating dict to the audio genres
audio_genres = {}

# %%
#Extract the audio genres
for i in df_tracks['id_artists'].tolist():
    audio_genres[i] = spotify.artist(i)['genres']

# %%
audio_genres
# Out:
# {'2xiIXseIJcq3nG7C8fHeBj': ['alternative metal',
#   'canadian metal',
#   'canadian rock',
#   'nu metal',
#   'post-grunge',
#   'rock'],
#  '246dkjvS1zLTtiykXe5h60': ['dfw rap', 'melodic rap', 'pop', 'rap'],
#  '1Xyo4u8uXC1ZmMpatF05PJ': ['canadian contemporary r&b',
#   'canadian pop',
#   'pop'],
#  '1URnnhqYAYcrqrcwql10ft': ['atl hip hop', 'hip hop', 'rap'],
#  '0Y5tJX1MQlPlqiwlOH1tJY': ['hip hop', 'rap', 'slap house'],
#  '7tYKF4w9nC0nq9CsPZTHyP': ['pop', 'r&b', 'rap'],
#  '4RddZ3iHvSpGV4dvATac9X': ['alternative metal',
#   'nu metal',
#   'rap metal',
#   'rap rock',
#   'rock'],
#  '4DWX7u8BV0vZIQSpJQQDWU': ['alternative metal', 'nu metal', 'post-grunge'],
#  '0iEtIxbK0KxaSlF7G42ZOp': ['hip hop', 'rap'],
#  '4DdkRBBYG6Yk9Ka8tdJ9BW': ['atl hip hop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'trap'],
#  '3TVXtAsR1Inumwj472S9r4': ['canadian hip hop',
#   'canadian pop',
#   'hip hop',
#   'pop rap',
#   'rap'],
#  '7dGJo4pcD2V6oG8kP0tJRR': ['detroit hip hop', 'hip hop', 'rap'],
#  '6XyY86QOPPrYVGvF9ch6wz': ['alternative metal',
#   'nu metal',
#   'post-grunge',
#   'rap metal',
#   'rock'],
#  '3q7HBObVc0L8jNeTe5Gofh': ['east coast hip hop',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'queens hip hop',
#   'rap'],
#  '7hJcb9fa4alzcOq3EaNPoG': ['g funk',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'west coast rap'],
#  '5XQ5Ie0v4Du9jLgY5p1ozb': [],
#  '5K4W6rqBFWDnAN6FQUkS6x': ['chicago rap', 'hip hop', 'rap'],
#  '0fA0VVWsXO9YnASrzqfmYu': ['hip hop', 'ohio hip hop', 'pop rap', 'rap'],
#  '13ubrt8QOOCPljQ2FL1Kca': ['east coast hip hop', 'hip hop', 'rap', 'trap'],
#  '2o5jDhtHVPhrJdv3cEQ99Z': ['big room',
#   'brostep',
#   'dutch edm',
#   'edm',
#   'house',
#   'pop dance',
#   'slap house',
#   'trance']}

# %%
#Append the audio attributes to the dataframe
df_tracks['genre'] = df_tracks['id_artists'].apply(lambda art_id: audio_genres[art_id])
df_tracks['acousticness'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['acousticness'])
df_tracks['speechiness'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['speechiness'])
df_tracks['key'] = df_tracks['id'].apply(lambda idd: str(audio_features[idd]['key']))
df_tracks['liveness'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['liveness'])
df_tracks['instrumentalness'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['instrumentalness'])
df_tracks['energy'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['energy'])
df_tracks['tempo'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['tempo'])
df_tracks['loudness'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['loudness'])
df_tracks['danceability'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['danceability'])
df_tracks['valence'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['valence'])

# %%
df_tracks
# Out:
#                         id              id_artists  \
# 0   56sk7jBpZV0CD31G9hEU3b  2xiIXseIJcq3nG7C8fHeBj
# 1   7piw04hPQZ1OHZ9Fq9JOXR  2xiIXseIJcq3nG7C8fHeBj
# 2   3HE50TVRquwXe9yv2HFoNL  2xiIXseIJcq3nG7C8fHeBj
# 3   0M955bMOoilikPXwKLYpoi  2xiIXseIJcq3nG7C8fHeBj
# 4   1nltpRhEiXikwDlVn4UADk  246dkjvS1zLTtiykXe5h60
# 5   5Ja2u1FPlVxrxeMWEa2dcn  246dkjvS1zLTtiykXe5h60
# 6   1D2L6MefbXon28PzIk9I3r  246dkjvS1zLTtiykXe5h60
# 7   5VuxWXbt7XENQCtE9TzpTv  246dkjvS1zLTtiykXe5h60
# 8   7dt6x5M1jzdTEt8oCbisTK  246dkjvS1zLTtiykXe5h60
# 9   0e7ipj03S05BNilyu5bRzt  246dkjvS1zLTtiykXe5h60
# 10  5QO79kh1waicV47BqGRL3g  1Xyo4u8uXC1ZmMpatF05PJ
# 11  7GUhiAHLoVy1V8ucQuZ3CB  1Xyo4u8uXC1ZmMpatF05PJ
# 12  7MXVkk9YMctZqd1Srtv4MB  1Xyo4u8uXC1ZmMpatF05PJ
# 13  2LBqCSwhJGcFQeTHMVGwy3  1Xyo4u8uXC1ZmMpatF05PJ
# 14  52eIcoLUM25zbQupAZYoFh  1URnnhqYAYcrqrcwql10ft
# 15  5u6vkDnOyaf8LsteDAj2ub  1URnnhqYAYcrqrcwql10ft
# 16  6OaVWaGfhXn70ZJfdVcabn  0Y5tJX1MQlPlqiwlOH1tJY
# 17  1xYpVRspgaLxdJLOTQkTjg  0Y5tJX1MQlPlqiwlOH1tJY
# 18  4SZepBIPDRwPaHIjAKwRDb  0Y5tJX1MQlPlqiwlOH1tJY
# 19  1i9lZvlaDdWDPyXEE95aiq  0Y5tJX1MQlPlqiwlOH1tJY
# 20  6koKhrBBcExADvWuOgceNZ  7tYKF4w9nC0nq9CsPZTHyP
# 21  6wsqVwoiVH2kde4k4KKAFU  0Y5tJX1MQlPlqiwlOH1tJY
# 22  5W8YXBz9MTIDyrpYaCg2Ky  4RddZ3iHvSpGV4dvATac9X
# 23  5RxCC8ecpIb6W9MVrJNmSF  4RddZ3iHvSpGV4dvATac9X
# 24  3UULkHdmLDqBDPmBYltoRE  4DWX7u8BV0vZIQSpJQQDWU
# 25  2o4AknH1hXnleCRW2rH45w  4DWX7u8BV0vZIQSpJQQDWU
# 26  1fewSx2d5KIZ04wsooEBOz  0iEtIxbK0KxaSlF7G42ZOp
# 27  7sO5G9EABYOXQKNPNiE9NR  4DdkRBBYG6Yk9Ka8tdJ9BW
# 28  2Hh3ETdQKrmSI3QS0hme7g  0iEtIxbK0KxaSlF7G42ZOp
# 29  1zi7xx7UVEFkmKfv06H8x0  3TVXtAsR1Inumwj472S9r4
# 30  28FGV3ORH14MYORd7s5dlU  7dGJo4pcD2V6oG8kP0tJRR
# 31  4xkOaSrkexMciUUogZKVTS  7dGJo4pcD2V6oG8kP0tJRR
# 32  4woTEX1wYOTGDqNXuavlRC  7dGJo4pcD2V6oG8kP0tJRR
# 33  2nLtzopw4rPReszdYBJU6h  6XyY86QOPPrYVGvF9ch6wz
# 34  0xpDDXbjPStXA8vwfKUWcI  3q7HBObVc0L8jNeTe5Gofh
# 35  0nKZeSrqH9u31NLoTUsYBR  7dGJo4pcD2V6oG8kP0tJRR
# 36  1IRNjfivqiDhzey02C11ge  3q7HBObVc0L8jNeTe5Gofh
# 37  52bHOlLu5iZO5huNdVUlue  6XyY86QOPPrYVGvF9ch6wz
# 38  47EJbrfrAAg4828kwQDUp2  7hJcb9fa4alzcOq3EaNPoG
# 39  0SNeQWVJQYpdLawJV91nGa  5XQ5Ie0v4Du9jLgY5p1ozb
# 40  0R7YVi7w41Dr9jU5vblAok  7hJcb9fa4alzcOq3EaNPoG
# 41  2RUFzxyUlI36KKy9Agkqze  5K4W6rqBFWDnAN6FQUkS6x
# 42  2GtaNlidzvK3hY78kCdsHa  0fA0VVWsXO9YnASrzqfmYu
# 43  2JPavCWYtpCSnyLwnLBvXZ  13ubrt8QOOCPljQ2FL1Kca
# 44  4go2hxLM6ijk0K76ZY0Nhd  13ubrt8QOOCPljQ2FL1Kca
# 45  3IvVQ1qmekCQ4LRwGCyIJA  13ubrt8QOOCPljQ2FL1Kca
# 46  4XoP1AkbOurU9CeZ2rMEz2  13ubrt8QOOCPljQ2FL1Kca
# 47  22Mme5vsZ688TMUieIHdx3  13ubrt8QOOCPljQ2FL1Kca
# 48  40H5libEZWrbkc8HTlXGbt  13ubrt8QOOCPljQ2FL1Kca
# 49  015IsLQFXbEm0f541N2qoX  2o5jDhtHVPhrJdv3cEQ99Z
#
#                                                  name           artists  \
# 0                                Animal I Have Become  Three Days Grace
# 1                                       Time of Dying  Three Days Grace
# 2                                      Never Too Late  Three Days Grace
# 3                         I Hate Everything About You  Three Days Grace
# 4                     One Right Now (with The Weeknd)       Post Malone
# 5                                      When I’m Alone       Post Malone
# 6                                         92 Explorer       Post Malone
# 7                     Spoil My Night (feat. Swae Lee)       Post Malone
# 8                                          Better Now       Post Malone
# 9                          rockstar (feat. 21 Savage)       Post Malone
# 10                                    Save Your Tears        The Weeknd
# 11             Popular (with Playboi Carti & Madonna)        The Weeknd
# 12                                            Starboy        The Weeknd
# 13                                        Die For You        The Weeknd
# 14                                             redrum         21 Savage
# 15             Ghostface Killers (feat. Travis Scott)         21 Savage
# 16                                      NO BYSTANDERS      Travis Scott
# 17                              STOP TRYING TO BE GOD      Travis Scott
# 18                                       R.I.P. SCREW      Travis Scott
# 19                   TELEKINESIS (feat. SZA & Future)      Travis Scott
# 20                     Open Arms (feat. Travis Scott)               SZA
# 21                                           I KNOW ?      Travis Scott
# 22                                        Last Resort        Papa Roach
# 23                                     ...To Be Loved        Papa Roach
# 24                                         Metalingus      Alter Bridge
# 25                                          Blackbird      Alter Bridge
# 26                          Space Cadet (feat. Gunna)      Metro Boomin
# 27                 Ric Flair Drip (with Metro Boomin)            Offset
# 28  Too Many Nights (feat. Don Toliver & with Future)      Metro Boomin
# 29                                          One Dance             Drake
# 30                     Not Alike (feat. Royce Da 5'9)            Eminem
# 31                                    Till I Collapse            Eminem
# 32                                           Superman            Eminem
# 33                                               Numb       Linkin Park
# 34                               Don't Worry 'Bout It           50 Cent
# 35                                     You Don't Know            Eminem
# 36                                           P.I.M.P.           50 Cent
# 37                                       High Voltage       Linkin Park
# 38   You Can Put It in a Zag, I'mma Put It in a Blunt        Snoop Dogg
# 39                Gang Of Marijuana (feat. Mac Lucci)        James Wade
# 40                                      Sweat - Remix        Snoop Dogg
# 41                                              POWER        Kanye West
# 42                                          Marijuana          Kid Cudi
# 43                                     Long Live A$AP        A$AP Rocky
# 44                                             Goldie        A$AP Rocky
# 45        PMW (All I Really Need) (feat. ScHoolboy Q)        A$AP Rocky
# 46  F**kin' Problems (feat. Drake, 2 Chainz & Kend...        A$AP Rocky
# 47  Wild for the Night (feat. Skrillex & Birdy Nam...        A$AP Rocky
# 48                                      Fashion Killa        A$AP Rocky
# 49                                         Red Lights            Tiësto
#
#     popularity                                              genre  \
# 0           77  [alternative metal, canadian metal, canadian r...
# 1           68  [alternative metal, canadian metal, canadian r...
# 2           71  [alternative metal, canadian metal, canadian r...
# 3           78  [alternative metal, canadian metal, canadian r...
# 4           71                   [dfw rap, melodic rap, pop, rap]
# 5           57                   [dfw rap, melodic rap, pop, rap]
# 6           69                   [dfw rap, melodic rap, pop, rap]
# 7           66                   [dfw rap, melodic rap, pop, rap]
# 8           82                   [dfw rap, melodic rap, pop, rap]
# 9           84                   [dfw rap, melodic rap, pop, rap]
# 10          89     [canadian contemporary r&b, canadian pop, pop]
# 11          86     [canadian contemporary r&b, canadian pop, pop]
# 12          93     [canadian contemporary r&b, canadian pop, pop]
# 13          89     [canadian contemporary r&b, canadian pop, pop]
# 14          96                        [atl hip hop, hip hop, rap]
# 15          72                        [atl hip hop, hip hop, rap]
# 16          75                         [hip hop, rap, slap house]
# 17          71                         [hip hop, rap, slap house]
# 18          69                         [hip hop, rap, slap house]
# 19          86                         [hip hop, rap, slap house]
# 20          81                                    [pop, r&b, rap]
# 21          91                         [hip hop, rap, slap house]
# 22          83  [alternative metal, nu metal, rap metal, rap r...
# 23          58  [alternative metal, nu metal, rap metal, rap r...
# 24          69         [alternative metal, nu metal, post-grunge]
# 25          56         [alternative metal, nu metal, post-grunge]
# 26          83                                     [hip hop, rap]
# 27          85         [atl hip hop, hip hop, pop rap, rap, trap]
# 28          88                                     [hip hop, rap]
# 29          90  [canadian hip hop, canadian pop, hip hop, pop ...
# 30          63                    [detroit hip hop, hip hop, rap]
# 31          86                    [detroit hip hop, hip hop, rap]
# 32          85                    [detroit hip hop, hip hop, rap]
# 33          88  [alternative metal, nu metal, post-grunge, rap...
# 34           0  [east coast hip hop, gangster rap, hip hop, po...
# 35          59                    [detroit hip hop, hip hop, rap]
# 36           0  [east coast hip hop, gangster rap, hip hop, po...
# 37           0  [alternative metal, nu metal, post-grunge, rap...
# 38          35  [g funk, gangster rap, hip hop, pop rap, rap, ...
# 39          17                                                 []
# 40          71  [g funk, gangster rap, hip hop, pop rap, rap, ...
# 41           0                        [chicago rap, hip hop, rap]
# 42          60              [hip hop, ohio hip hop, pop rap, rap]
# 43           0           [east coast hip hop, hip hop, rap, trap]
# 44           0           [east coast hip hop, hip hop, rap, trap]
# 45           0           [east coast hip hop, hip hop, rap, trap]
# 46           0           [east coast hip hop, hip hop, rap, trap]
# 47           0           [east coast hip hop, hip hop, rap, trap]
# 48           0           [east coast hip hop, hip hop, rap, trap]
# 49           0  [big room, brostep, dutch edm, edm, house, pop...
#
#     acousticness  speechiness key  liveness  instrumentalness  energy  \
# 0       0.000684       0.0339   8    0.1260          0.000000   0.853
# 1       0.001050       0.0567   0    0.5200          0.000000   0.873
# 2       0.008380       0.0371   2    0.1630          0.000000   0.778
# 3       0.004610       0.0421   6    0.1390          0.000000   0.830
# 4       0.036300       0.0477   1    0.1030          0.000000   0.764
# 5       0.034600       0.0528  10    0.1550          0.000000   0.656
# 6       0.265000       0.0476   7    0.1140          0.000001   0.733
# 7       0.341000       0.0340   1    0.1060          0.000024   0.717
# 8       0.331000       0.0400  10    0.1350          0.000000   0.578
# 9       0.124000       0.0712   5    0.1310          0.000070   0.520
# 10      0.021200       0.0309   0    0.5430          0.000012   0.826
# 11      0.060400       0.2000   1    0.3820          0.000084   0.668
# 12      0.141000       0.2760   7    0.1370          0.000006   0.587
# 13      0.111000       0.0615   1    0.1340          0.000000   0.525
# 14      0.005290       0.0481   2    0.5000          0.000224   0.740
# 15      0.333000       0.1560   2    0.3420          0.000013   0.435
# 16      0.020400       0.0712   1    0.4110          0.000000   0.811
# 17      0.221000       0.0628   4    0.1350          0.000000   0.567
# 18      0.389000       0.2910   0    0.1110          0.000016   0.609
# 19      0.575000       0.0281   5    0.1680          0.000000   0.535
# 20      0.753000       0.1380   9    0.1460          0.014400   0.586
# 21      0.018600       0.0539   5    0.1040          0.000000   0.619
# 22      0.000481       0.0603   4    0.2010          0.000820   0.890
# 23      0.004730       0.0751   8    0.5090          0.000000   0.977
# 24      0.000009       0.1080   8    0.0958          0.000000   0.981
# 25      0.004990       0.0448   6    0.1160          0.012600   0.806
# 26      0.368000       0.0645   5    0.2380          0.000017   0.464
# 27      0.149000       0.2060   9    0.1140          0.000051   0.428
# 28      0.189000       0.0464   7    0.1220          0.000024   0.671
# 29      0.007760       0.0536   1    0.3290          0.001800   0.625
# 30      0.069200       0.3200  10    0.3390          0.000000   0.756
# 31      0.062200       0.1860   1    0.0816          0.000000   0.847
# 32      0.021500       0.0564   4    0.2950          0.000000   0.755
# 33      0.004600       0.0381   9    0.6390          0.000000   0.863
# 34      0.560000       0.2790   5    0.1550          0.000000   0.692
# 35      0.011600       0.1330  10    0.0957          0.000000   0.864
# 36      0.052100       0.3510  10    0.0328          0.000015   0.773
# 37      0.100000       0.1820   7    0.2740          0.000003   0.969
# 38      0.103000       0.3070   8    0.1530          0.000000   0.583
# 39      0.674000       0.4220   1    0.0856          0.000000   0.306
# 40      0.059700       0.0300   7    0.0826          0.001370   0.732
# 41      0.019300       0.1300   0    0.8250          0.000000   0.907
# 42      0.829000       0.0273   8    0.2720          0.829000   0.403
# 43      0.610000       0.3510   0    0.1150          0.000000   0.832
# 44      0.220000       0.2410   1    0.3780          0.000030   0.843
# 45      0.000367       0.0526   1    0.3200          0.000000   0.752
# 46      0.020800       0.2630   1    0.1140          0.000001   0.687
# 47      0.045200       0.3360   2    0.1210          0.000000   0.857
# 48      0.315000       0.1520  11    0.5310          0.000000   0.820
# 49      0.000629       0.0366  10    0.1210          0.000001   0.830
#
#       tempo  loudness  danceability  valence
# 0   122.023    -3.668         0.553    0.506
# 1   198.387    -3.668         0.306    0.452
# 2   149.864    -4.680         0.433    0.217
# 3    89.342    -5.157         0.498    0.453
# 4    97.023    -5.411         0.682    0.701
# 5   140.107    -6.121         0.485    0.106
# 6   146.046    -4.811         0.798    0.861
# 7   160.981    -2.714         0.672    0.225
# 8   145.038    -5.804         0.680    0.341
# 9   159.801    -6.136         0.585    0.129
# 10  118.051    -5.487         0.680    0.644
# 11   99.018    -6.243         0.854    0.833
# 12  186.003    -7.015         0.679    0.486
# 13  133.629    -7.163         0.586    0.508
# 14  172.089    -8.445         0.624    0.246
# 15   82.996    -7.033         0.782    0.242
# 16  147.045    -3.225         0.731    0.426
# 17  150.009    -3.738         0.588    0.113
# 18   74.946    -5.978         0.607    0.556
# 19   82.826    -4.854         0.458    0.216
# 20   78.259    -7.612         0.434    0.239
# 21  117.995    -4.441         0.927    0.817
# 22   90.598    -3.719         0.589    0.692
# 23   96.047    -3.162         0.478    0.482
# 24  109.905    -3.268         0.496    0.163
# 25  149.463    -4.714         0.279    0.132
# 26  109.004    -9.789         0.901    0.638
# 27  100.007    -8.280         0.880    0.333
# 28   88.048    -4.392         0.684    0.156
# 29  103.967    -5.609         0.792    0.370
# 30  140.005    -3.746         0.904    0.342
# 31  171.447    -3.237         0.548    0.100
# 32  130.027    -3.138         0.802    0.580
# 33  110.018    -4.153         0.496    0.243
# 34  151.093    -6.001         0.796    0.965
# 35   85.475    -1.847         0.767    0.747
# 36   78.660    -3.050         0.684    0.873
# 37   94.003    -4.201         0.594    0.267
# 38   93.940    -8.604         0.646    0.519
# 39   67.389   -16.517         0.599    0.223
# 40  130.020    -5.636         0.813    0.731
# 41  154.000    -4.757         0.539    0.553
# 42  140.986    -9.809         0.673    0.540
# 43  130.042    -4.939         0.716    0.399
# 44   81.958    -4.919         0.680    0.743
# 45  130.022    -4.552         0.697    0.269
# 46   96.006    -6.816         0.869    0.668
# 47  140.017    -4.185         0.756    0.688
# 48  140.042    -5.214         0.794    0.793
# 49  124.989    -4.801         0.654    0.548

# %%
df_tracks['genre'] = [i[0] if i else None for i in df_tracks['genre']]

# %%
df_tracks
# Out:
#                         id              id_artists  \
# 0   56sk7jBpZV0CD31G9hEU3b  2xiIXseIJcq3nG7C8fHeBj
# 1   7piw04hPQZ1OHZ9Fq9JOXR  2xiIXseIJcq3nG7C8fHeBj
# 2   3HE50TVRquwXe9yv2HFoNL  2xiIXseIJcq3nG7C8fHeBj
# 3   0M955bMOoilikPXwKLYpoi  2xiIXseIJcq3nG7C8fHeBj
# 4   1nltpRhEiXikwDlVn4UADk  246dkjvS1zLTtiykXe5h60
# 5   5Ja2u1FPlVxrxeMWEa2dcn  246dkjvS1zLTtiykXe5h60
# 6   1D2L6MefbXon28PzIk9I3r  246dkjvS1zLTtiykXe5h60
# 7   5VuxWXbt7XENQCtE9TzpTv  246dkjvS1zLTtiykXe5h60
# 8   7dt6x5M1jzdTEt8oCbisTK  246dkjvS1zLTtiykXe5h60
# 9   0e7ipj03S05BNilyu5bRzt  246dkjvS1zLTtiykXe5h60
# 10  5QO79kh1waicV47BqGRL3g  1Xyo4u8uXC1ZmMpatF05PJ
# 11  7GUhiAHLoVy1V8ucQuZ3CB  1Xyo4u8uXC1ZmMpatF05PJ
# 12  7MXVkk9YMctZqd1Srtv4MB  1Xyo4u8uXC1ZmMpatF05PJ
# 13  2LBqCSwhJGcFQeTHMVGwy3  1Xyo4u8uXC1ZmMpatF05PJ
# 14  52eIcoLUM25zbQupAZYoFh  1URnnhqYAYcrqrcwql10ft
# 15  5u6vkDnOyaf8LsteDAj2ub  1URnnhqYAYcrqrcwql10ft
# 16  6OaVWaGfhXn70ZJfdVcabn  0Y5tJX1MQlPlqiwlOH1tJY
# 17  1xYpVRspgaLxdJLOTQkTjg  0Y5tJX1MQlPlqiwlOH1tJY
# 18  4SZepBIPDRwPaHIjAKwRDb  0Y5tJX1MQlPlqiwlOH1tJY
# 19  1i9lZvlaDdWDPyXEE95aiq  0Y5tJX1MQlPlqiwlOH1tJY
# 20  6koKhrBBcExADvWuOgceNZ  7tYKF4w9nC0nq9CsPZTHyP
# 21  6wsqVwoiVH2kde4k4KKAFU  0Y5tJX1MQlPlqiwlOH1tJY
# 22  5W8YXBz9MTIDyrpYaCg2Ky  4RddZ3iHvSpGV4dvATac9X
# 23  5RxCC8ecpIb6W9MVrJNmSF  4RddZ3iHvSpGV4dvATac9X
# 24  3UULkHdmLDqBDPmBYltoRE  4DWX7u8BV0vZIQSpJQQDWU
# 25  2o4AknH1hXnleCRW2rH45w  4DWX7u8BV0vZIQSpJQQDWU
# 26  1fewSx2d5KIZ04wsooEBOz  0iEtIxbK0KxaSlF7G42ZOp
# 27  7sO5G9EABYOXQKNPNiE9NR  4DdkRBBYG6Yk9Ka8tdJ9BW
# 28  2Hh3ETdQKrmSI3QS0hme7g  0iEtIxbK0KxaSlF7G42ZOp
# 29  1zi7xx7UVEFkmKfv06H8x0  3TVXtAsR1Inumwj472S9r4
# 30  28FGV3ORH14MYORd7s5dlU  7dGJo4pcD2V6oG8kP0tJRR
# 31  4xkOaSrkexMciUUogZKVTS  7dGJo4pcD2V6oG8kP0tJRR
# 32  4woTEX1wYOTGDqNXuavlRC  7dGJo4pcD2V6oG8kP0tJRR
# 33  2nLtzopw4rPReszdYBJU6h  6XyY86QOPPrYVGvF9ch6wz
# 34  0xpDDXbjPStXA8vwfKUWcI  3q7HBObVc0L8jNeTe5Gofh
# 35  0nKZeSrqH9u31NLoTUsYBR  7dGJo4pcD2V6oG8kP0tJRR
# 36  1IRNjfivqiDhzey02C11ge  3q7HBObVc0L8jNeTe5Gofh
# 37  52bHOlLu5iZO5huNdVUlue  6XyY86QOPPrYVGvF9ch6wz
# 38  47EJbrfrAAg4828kwQDUp2  7hJcb9fa4alzcOq3EaNPoG
# 39  0SNeQWVJQYpdLawJV91nGa  5XQ5Ie0v4Du9jLgY5p1ozb
# 40  0R7YVi7w41Dr9jU5vblAok  7hJcb9fa4alzcOq3EaNPoG
# 41  2RUFzxyUlI36KKy9Agkqze  5K4W6rqBFWDnAN6FQUkS6x
# 42  2GtaNlidzvK3hY78kCdsHa  0fA0VVWsXO9YnASrzqfmYu
# 43  2JPavCWYtpCSnyLwnLBvXZ  13ubrt8QOOCPljQ2FL1Kca
# 44  4go2hxLM6ijk0K76ZY0Nhd  13ubrt8QOOCPljQ2FL1Kca
# 45  3IvVQ1qmekCQ4LRwGCyIJA  13ubrt8QOOCPljQ2FL1Kca
# 46  4XoP1AkbOurU9CeZ2rMEz2  13ubrt8QOOCPljQ2FL1Kca
# 47  22Mme5vsZ688TMUieIHdx3  13ubrt8QOOCPljQ2FL1Kca
# 48  40H5libEZWrbkc8HTlXGbt  13ubrt8QOOCPljQ2FL1Kca
# 49  015IsLQFXbEm0f541N2qoX  2o5jDhtHVPhrJdv3cEQ99Z
#
#                                                  name           artists  \
# 0                                Animal I Have Become  Three Days Grace
# 1                                       Time of Dying  Three Days Grace
# 2                                      Never Too Late  Three Days Grace
# 3                         I Hate Everything About You  Three Days Grace
# 4                     One Right Now (with The Weeknd)       Post Malone
# 5                                      When I’m Alone       Post Malone
# 6                                         92 Explorer       Post Malone
# 7                     Spoil My Night (feat. Swae Lee)       Post Malone
# 8                                          Better Now       Post Malone
# 9                          rockstar (feat. 21 Savage)       Post Malone
# 10                                    Save Your Tears        The Weeknd
# 11             Popular (with Playboi Carti & Madonna)        The Weeknd
# 12                                            Starboy        The Weeknd
# 13                                        Die For You        The Weeknd
# 14                                             redrum         21 Savage
# 15             Ghostface Killers (feat. Travis Scott)         21 Savage
# 16                                      NO BYSTANDERS      Travis Scott
# 17                              STOP TRYING TO BE GOD      Travis Scott
# 18                                       R.I.P. SCREW      Travis Scott
# 19                   TELEKINESIS (feat. SZA & Future)      Travis Scott
# 20                     Open Arms (feat. Travis Scott)               SZA
# 21                                           I KNOW ?      Travis Scott
# 22                                        Last Resort        Papa Roach
# 23                                     ...To Be Loved        Papa Roach
# 24                                         Metalingus      Alter Bridge
# 25                                          Blackbird      Alter Bridge
# 26                          Space Cadet (feat. Gunna)      Metro Boomin
# 27                 Ric Flair Drip (with Metro Boomin)            Offset
# 28  Too Many Nights (feat. Don Toliver & with Future)      Metro Boomin
# 29                                          One Dance             Drake
# 30                     Not Alike (feat. Royce Da 5'9)            Eminem
# 31                                    Till I Collapse            Eminem
# 32                                           Superman            Eminem
# 33                                               Numb       Linkin Park
# 34                               Don't Worry 'Bout It           50 Cent
# 35                                     You Don't Know            Eminem
# 36                                           P.I.M.P.           50 Cent
# 37                                       High Voltage       Linkin Park
# 38   You Can Put It in a Zag, I'mma Put It in a Blunt        Snoop Dogg
# 39                Gang Of Marijuana (feat. Mac Lucci)        James Wade
# 40                                      Sweat - Remix        Snoop Dogg
# 41                                              POWER        Kanye West
# 42                                          Marijuana          Kid Cudi
# 43                                     Long Live A$AP        A$AP Rocky
# 44                                             Goldie        A$AP Rocky
# 45        PMW (All I Really Need) (feat. ScHoolboy Q)        A$AP Rocky
# 46  F**kin' Problems (feat. Drake, 2 Chainz & Kend...        A$AP Rocky
# 47  Wild for the Night (feat. Skrillex & Birdy Nam...        A$AP Rocky
# 48                                      Fashion Killa        A$AP Rocky
# 49                                         Red Lights            Tiësto
#
#     popularity                      genre  acousticness  speechiness key  \
# 0           77          alternative metal      0.000684       0.0339   8
# 1           68          alternative metal      0.001050       0.0567   0
# 2           71          alternative metal      0.008380       0.0371   2
# 3           78          alternative metal      0.004610       0.0421   6
# 4           71                    dfw rap      0.036300       0.0477   1
# 5           57                    dfw rap      0.034600       0.0528  10
# 6           69                    dfw rap      0.265000       0.0476   7
# 7           66                    dfw rap      0.341000       0.0340   1
# 8           82                    dfw rap      0.331000       0.0400  10
# 9           84                    dfw rap      0.124000       0.0712   5
# 10          89  canadian contemporary r&b      0.021200       0.0309   0
# 11          86  canadian contemporary r&b      0.060400       0.2000   1
# 12          93  canadian contemporary r&b      0.141000       0.2760   7
# 13          89  canadian contemporary r&b      0.111000       0.0615   1
# 14          96                atl hip hop      0.005290       0.0481   2
# 15          72                atl hip hop      0.333000       0.1560   2
# 16          75                    hip hop      0.020400       0.0712   1
# 17          71                    hip hop      0.221000       0.0628   4
# 18          69                    hip hop      0.389000       0.2910   0
# 19          86                    hip hop      0.575000       0.0281   5
# 20          81                        pop      0.753000       0.1380   9
# 21          91                    hip hop      0.018600       0.0539   5
# 22          83          alternative metal      0.000481       0.0603   4
# 23          58          alternative metal      0.004730       0.0751   8
# 24          69          alternative metal      0.000009       0.1080   8
# 25          56          alternative metal      0.004990       0.0448   6
# 26          83                    hip hop      0.368000       0.0645   5
# 27          85                atl hip hop      0.149000       0.2060   9
# 28          88                    hip hop      0.189000       0.0464   7
# 29          90           canadian hip hop      0.007760       0.0536   1
# 30          63            detroit hip hop      0.069200       0.3200  10
# 31          86            detroit hip hop      0.062200       0.1860   1
# 32          85            detroit hip hop      0.021500       0.0564   4
# 33          88          alternative metal      0.004600       0.0381   9
# 34           0         east coast hip hop      0.560000       0.2790   5
# 35          59            detroit hip hop      0.011600       0.1330  10
# 36           0         east coast hip hop      0.052100       0.3510  10
# 37           0          alternative metal      0.100000       0.1820   7
# 38          35                     g funk      0.103000       0.3070   8
# 39          17                       None      0.674000       0.4220   1
# 40          71                     g funk      0.059700       0.0300   7
# 41           0                chicago rap      0.019300       0.1300   0
# 42          60                    hip hop      0.829000       0.0273   8
# 43           0         east coast hip hop      0.610000       0.3510   0
# 44           0         east coast hip hop      0.220000       0.2410   1
# 45           0         east coast hip hop      0.000367       0.0526   1
# 46           0         east coast hip hop      0.020800       0.2630   1
# 47           0         east coast hip hop      0.045200       0.3360   2
# 48           0         east coast hip hop      0.315000       0.1520  11
# 49           0                   big room      0.000629       0.0366  10
#
#     liveness  instrumentalness  energy    tempo  loudness  danceability  \
# 0     0.1260          0.000000   0.853  122.023    -3.668         0.553
# 1     0.5200          0.000000   0.873  198.387    -3.668         0.306
# 2     0.1630          0.000000   0.778  149.864    -4.680         0.433
# 3     0.1390          0.000000   0.830   89.342    -5.157         0.498
# 4     0.1030          0.000000   0.764   97.023    -5.411         0.682
# 5     0.1550          0.000000   0.656  140.107    -6.121         0.485
# 6     0.1140          0.000001   0.733  146.046    -4.811         0.798
# 7     0.1060          0.000024   0.717  160.981    -2.714         0.672
# 8     0.1350          0.000000   0.578  145.038    -5.804         0.680
# 9     0.1310          0.000070   0.520  159.801    -6.136         0.585
# 10    0.5430          0.000012   0.826  118.051    -5.487         0.680
# 11    0.3820          0.000084   0.668   99.018    -6.243         0.854
# 12    0.1370          0.000006   0.587  186.003    -7.015         0.679
# 13    0.1340          0.000000   0.525  133.629    -7.163         0.586
# 14    0.5000          0.000224   0.740  172.089    -8.445         0.624
# 15    0.3420          0.000013   0.435   82.996    -7.033         0.782
# 16    0.4110          0.000000   0.811  147.045    -3.225         0.731
# 17    0.1350          0.000000   0.567  150.009    -3.738         0.588
# 18    0.1110          0.000016   0.609   74.946    -5.978         0.607
# 19    0.1680          0.000000   0.535   82.826    -4.854         0.458
# 20    0.1460          0.014400   0.586   78.259    -7.612         0.434
# 21    0.1040          0.000000   0.619  117.995    -4.441         0.927
# 22    0.2010          0.000820   0.890   90.598    -3.719         0.589
# 23    0.5090          0.000000   0.977   96.047    -3.162         0.478
# 24    0.0958          0.000000   0.981  109.905    -3.268         0.496
# 25    0.1160          0.012600   0.806  149.463    -4.714         0.279
# 26    0.2380          0.000017   0.464  109.004    -9.789         0.901
# 27    0.1140          0.000051   0.428  100.007    -8.280         0.880
# 28    0.1220          0.000024   0.671   88.048    -4.392         0.684
# 29    0.3290          0.001800   0.625  103.967    -5.609         0.792
# 30    0.3390          0.000000   0.756  140.005    -3.746         0.904
# 31    0.0816          0.000000   0.847  171.447    -3.237         0.548
# 32    0.2950          0.000000   0.755  130.027    -3.138         0.802
# 33    0.6390          0.000000   0.863  110.018    -4.153         0.496
# 34    0.1550          0.000000   0.692  151.093    -6.001         0.796
# 35    0.0957          0.000000   0.864   85.475    -1.847         0.767
# 36    0.0328          0.000015   0.773   78.660    -3.050         0.684
# 37    0.2740          0.000003   0.969   94.003    -4.201         0.594
# 38    0.1530          0.000000   0.583   93.940    -8.604         0.646
# 39    0.0856          0.000000   0.306   67.389   -16.517         0.599
# 40    0.0826          0.001370   0.732  130.020    -5.636         0.813
# 41    0.8250          0.000000   0.907  154.000    -4.757         0.539
# 42    0.2720          0.829000   0.403  140.986    -9.809         0.673
# 43    0.1150          0.000000   0.832  130.042    -4.939         0.716
# 44    0.3780          0.000030   0.843   81.958    -4.919         0.680
# 45    0.3200          0.000000   0.752  130.022    -4.552         0.697
# 46    0.1140          0.000001   0.687   96.006    -6.816         0.869
# 47    0.1210          0.000000   0.857  140.017    -4.185         0.756
# 48    0.5310          0.000000   0.820  140.042    -5.214         0.794
# 49    0.1210          0.000001   0.830  124.989    -4.801         0.654
#
#     valence
# 0     0.506
# 1     0.452
# 2     0.217
# 3     0.453
# 4     0.701
# 5     0.106
# 6     0.861
# 7     0.225
# 8     0.341
# 9     0.129
# 10    0.644
# 11    0.833
# 12    0.486
# 13    0.508
# 14    0.246
# 15    0.242
# 16    0.426
# 17    0.113
# 18    0.556
# 19    0.216
# 20    0.239
# 21    0.817
# 22    0.692
# 23    0.482
# 24    0.163
# 25    0.132
# 26    0.638
# 27    0.333
# 28    0.156
# 29    0.370
# 30    0.342
# 31    0.100
# 32    0.580
# 33    0.243
# 34    0.965
# 35    0.747
# 36    0.873
# 37    0.267
# 38    0.519
# 39    0.223
# 40    0.731
# 41    0.553
# 42    0.540
# 43    0.399
# 44    0.743
# 45    0.269
# 46    0.668
# 47    0.688
# 48    0.793
# 49    0.548

# %%
#Let's pick up a song randomly 
random_song = random.randint(0,len(df_tracks)-1)

# %%
df_random_song = df_tracks[random_song:random_song+1]

# %%
random_song
# Out:
# 33

# %%
df_random_song
# Out:
#                         id              id_artists  name      artists  \
# 33  2nLtzopw4rPReszdYBJU6h  6XyY86QOPPrYVGvF9ch6wz  Numb  Linkin Park
#
#     popularity              genre  acousticness  speechiness key  liveness  \
# 33          88  alternative metal        0.0046       0.0381   9     0.639
#
#     instrumentalness  energy    tempo  loudness  danceability  valence
# 33               0.0   0.863  110.018    -4.153         0.496    0.243

# %%
spark_songs.show(5)
# Out:
# +--------+--------------------+--------------------+--------------------+----------+-----------+-------------+--------------------+--------------------+------------+------+----+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+--------------------+
# |order_id|                  id|                name|               genre|popularity|duration_ms|      artists|          id_artists|        release_date|danceability|energy| key|loudness|mode|speechiness|acousticness|instrumentalness|liveness|valence|  tempo|time_signature|           timestamp|
# +--------+--------------------+--------------------+--------------------+----------+-----------+-------------+--------------------+--------------------+------------+------+----+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+--------------------+
# |      76|3FmS1F9CSpVoHIMss...|       Red Dragonfly|experimental hip hop|         0|   282624.0|  Black Taffy|0Y9vfLdeXoP0Mu1rL...|          2018-07-26|       0.181| 0.355|   5| -13.951|   1|     0.0368|       0.171|           0.729|   0.321|  0.134|156.977|           3.0|2024-03-13 10:40:...|
# |      77|47xKNeYXHnsFcISHz...|Searching For Memory|  african electronic|      NULL|       15.0|       281714|        Lamin Fofana|6j6rR9uFQ6yYMDcxm...|        NULL| 0.324|NULL|     5.0|NULL|        0.0|      0.0525|           0.946|   0.911|  0.102| 0.0473|        105.03|2024-03-13 10:40:...|
# |      78|5Ov9SR4f9SzJWkNQy...|Far From the Eyes...|                 nan|         0|   329639.0|   C.L.A.W.S.|3LBsNwoZrEkeaSK9V...|          2018-07-27|        0.65| 0.918|  11|  -6.898|   0|     0.0573|      0.0767|           0.818|   0.145|  0.279|115.992|           4.0|2024-03-13 10:40:...|
# |      79|07ZIVNs0d8TQqoVfW...|       January's End|                 nan|         0|   408248.0|Nigil Caenaan|4RjBcw1cZ7lc9luFv...|          2018-07-26|       0.786| 0.855|   1|  -7.625|   1|     0.0596|     0.00633|           0.883|   0.111| 0.0373|134.006|           4.0|2024-03-13 10:40:...|
# |      80|3EXE6xuaGxSwgW9p2...|          Around You|                 nan|        30|   333559.0|Zane Schaffer|1stp6XCHbjsyVmOYG...|          2018-07-14|       0.743|  0.52|   1| -13.847|   1|      0.063|      0.0305|           0.827|   0.205|  0.175|117.995|           4.0|2024-03-13 10:40:...|
# +--------+--------------------+--------------------+--------------------+----------+-----------+-------------+--------------------+--------------------+------------+------+----+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+--------------------+
# only showing top 5 rows

# %%
spark_songs.columns
# Out:
# ['order_id',
#  'id',
#  'name',
#  'genre',
#  'popularity',
#  'duration_ms',
#  'artists',
#  'id_artists',
#  'release_date',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'time_signature',
#  'timestamp']

# %%
# We dont need those columns anymore
spark_songs = spark_songs.drop('order_id', 
                               'mode', 
                               'release_date', 
                               'time_signature', 
                               'duration_ms',
                               'timestamp',
                               'id_artists')

# %%
#create a dataframe with the randomly chosen song 
df_sp = spark.createDataFrame(df_random_song)

# %%
df_sp = df_sp.drop('id_artists')

# %%
df_sp.show()
# Out:
# +--------------------+----+-----------+----------+-----------------+------------+-----------+---+--------+----------------+------+-------+--------+------------+-------+
# |                  id|name|    artists|popularity|            genre|acousticness|speechiness|key|liveness|instrumentalness|energy|  tempo|loudness|danceability|valence|
# +--------------------+----+-----------+----------+-----------------+------------+-----------+---+--------+----------------+------+-------+--------+------------+-------+
# |2nLtzopw4rPReszdY...|Numb|Linkin Park|        88|alternative metal|      0.0046|     0.0381|  9|   0.639|             0.0| 0.863|110.018|  -4.153|       0.496|  0.243|
# +--------------------+----+-----------+----------+-----------------+------------+-----------+---+--------+----------------+------+-------+--------+------------+-------+

# %%
df_sp.columns
# Out:
# ['id',
#  'name',
#  'artists',
#  'popularity',
#  'genre',
#  'acousticness',
#  'speechiness',
#  'key',
#  'liveness',
#  'instrumentalness',
#  'energy',
#  'tempo',
#  'loudness',
#  'danceability',
#  'valence']

# %%
spark_songs.columns
# Out:
# ['id',
#  'name',
#  'genre',
#  'popularity',
#  'artists',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo']

# %%
df = spark_songs.union(df_sp)

# %% [markdown]
# ## Data Pre-proccessing

# %%
#Label-encode column "genres"
string_indexer = StringIndexer(inputCol= 'genre', outputCol='genre_encoded')
model_string_indexer = string_indexer.fit(df)
df = model_string_indexer.setHandleInvalid("skip").transform(df)

# %%
df.columns
# Out:
# ['id',
#  'name',
#  'genre',
#  'popularity',
#  'artists',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'genre_encoded']

# %%
vector = VectorAssembler(inputCols = ['danceability',
                                     'energy',
                                     'loudness',
                                     'speechiness',
                                     'acousticness',
                                     'instrumentalness',
                                     'liveness',
                                     'valence',
                                     'tempo',
                                     'genre_encoded'], 
                        outputCol = 'song_features')

# %%
assembled = vector.setHandleInvalid("skip").transform(df)

# %%
#Preparing stander 
std = StandardScaler(inputCol= 'song_features', outputCol= 'standardized')

# %%
#Train stander 
scale = std.fit(assembled)

# %%
df = scale.transform(assembled)

# %%
df.show(5)
# Out:
# +--------------------+--------------------+--------------------+----------+-------------+------------+------+---+--------+-----------+------------+----------------+--------+-------+-------+-------------+--------------------+--------------------+
# |                  id|                name|               genre|popularity|      artists|danceability|energy|key|loudness|speechiness|acousticness|instrumentalness|liveness|valence|  tempo|genre_encoded|       song_features|        standardized|
# +--------------------+--------------------+--------------------+----------+-------------+------------+------+---+--------+-----------+------------+----------------+--------+-------+-------+-------------+--------------------+--------------------+
# |3FmS1F9CSpVoHIMss...|       Red Dragonfly|experimental hip hop|         0|  Black Taffy|       0.181| 0.355|  5| -13.951|     0.0368|       0.171|           0.729|   0.321|  0.134|156.977|         85.0|[0.181,0.355,-13....|[1.07126440842253...|
# |5Ov9SR4f9SzJWkNQy...|Far From the Eyes...|                 nan|         0|   C.L.A.W.S.|        0.65| 0.918| 11|  -6.898|     0.0573|      0.0767|           0.818|   0.145|  0.279|115.992|          0.0|[0.65,0.918,-6.89...|[3.84708212969418...|
# |07ZIVNs0d8TQqoVfW...|       January's End|                 nan|         0|Nigil Caenaan|       0.786| 0.855|  1|  -7.625|     0.0596|     0.00633|           0.883|   0.111| 0.0373|134.006|          0.0|[0.786,0.855,-7.6...|[4.65201008298404...|
# |3EXE6xuaGxSwgW9p2...|          Around You|                 nan|        30|Zane Schaffer|       0.743|  0.52|  1| -13.847|      0.063|      0.0305|           0.827|   0.205|  0.175|117.995|          0.0|[0.743,0.52,-13.8...|[4.39751080363504...|
# |0btYDDy8lTn8AFiSv...|           Lifeguard|                 nan|        11|      KingJet|        0.76| 0.576|  7|  -6.792|      0.055|      0.0096|         0.00619|   0.132|  0.724|100.016|          0.0|[0.76,0.576,-6.79...|[4.49812679779627...|
# +--------------------+--------------------+--------------------+----------+-------------+------------+------+---+--------+-----------+------------+----------------+--------+-------+-------+-------------+--------------------+--------------------+
# only showing top 5 rows

# %%
df.columns
# Out:
# ['id',
#  'name',
#  'genre',
#  'popularity',
#  'artists',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'genre_encoded',
#  'song_features',
#  'standardized']

# %% [markdown]
# ## Machine learning with unsupervisioned learning

# %%
kmeans_object = KMeans(featuresCol= 'standardized', k = 4)

# %%
model_kmeans = kmeans_object.fit(df)

# %%
df_output = model_kmeans.transform(df)

# %%
df_output.columns
# Out:
# ['id',
#  'name',
#  'genre',
#  'popularity',
#  'artists',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'genre_encoded',
#  'song_features',
#  'standardized',
#  'prediction']

# %% [markdown]
# # Recommender System

# %% [markdown]
# ## Content-based Filtering: Content-based Filtering is a recommender system technique that uses data about user preferences and attributes of items to model the likelihood a given user will like a specific item.
#
# ## In the Spark environment, the Content-based algorithm doesn't exists, so we have to build one from the beginning

# %%
# Class
class RecoSystem():
    
    # Método construtor
    def __init__(self, data):
        self.data_ = data
    
    # Método de recomendação
    def Recomm(self, name_song, amount = 3):
        
        # Lista para as distâncias
        distances = []
        
        # Seleciona a música
        song = self.data_[(self.data_.name.str.lower() == name_song.lower())].values[0]
        res_dt = self.data_[self.data_.name.str.lower() != name_song.lower()]
        
        # Loop para o cálculo das distâncias
        for i_song in tqdm(res_dt.values):
            
            # Inicializa a distância
            distance = 0
            
            # Loop para calcular a distância
            for col in np.arange(len(res_dt.columns)):
                if not col in [0,1,2,3,15]:
                    distance = distance + np.absolute(float(song[col]) - float(i_song[col]))
            
            # Adiciona na lista de distâncias
            distances.append(distance)
        
        res_dt['distance'] = distances
        res_dt = res_dt.sort_values('distance')
        
        columns = ['id','name', 
                   'artists',
                   'genre',
                   'acousticness', 
                   'liveness', 
                   'instrumentalness', 
                   'energy', 
                   'danceability', 
                   'valence']
        
        return res_dt[columns][:amount]

# %%
datalabel = df_output.select('id',
                             'name',
                             'artists',
                             'genre',
                             'genre_encoded',
                             'danceability',
                             'energy',
                             'key',
                             'loudness',
                             'speechiness',
                             'acousticness',
                             'instrumentalness',
                             'liveness',
                             'valence',
                             'tempo',
                             'prediction')

# %%
df_final = datalabel.toPandas()
df_final.drop(df_final[df_final['artists'] == '0'].index, inplace = True)
df_final.drop_duplicates(inplace = True)
df_final.drop(df_final[df_final['danceability'] == 0.0000].index, inplace = True)
df_final.drop(df_final[df_final['liveness'] == 0.000].index, inplace = True)
df_final.drop(df_final[df_final['instrumentalness'] == 0.000000].index, inplace = True)
df_final.drop(df_final[df_final['energy'] == 0.0000].index, inplace = True)
df_final.drop(df_final[df_final['danceability'] == 0.000].index, inplace = True)
df_final.drop(df_final[df_final['valence'] == 0.000].index, inplace = True)
df_final.dropna(inplace = True)

# %%
df_final.shape
# Out:
# (291, 16)

# %%
df_final.columns
# Out:
# Index(['id', 'name', 'artists', 'genre', 'genre_encoded', 'danceability',
#        'energy', 'key', 'loudness', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'prediction'],
#       dtype='object')

# %%
reco_obj = RecoSystem(df_final)

# %%
music = df_random_song['name'].tolist()[0]

# %%
print(music)
# Out:
# Numb

# %%
recommendation = reco_obj.Recomm(music)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 290/290 [00:00<00:00, 29011.79it/s]
# C:\Users\mathe\AppData\Local\Temp\ipykernel_12184\135654574.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_dt['distance'] = distances

# %%
recommendation
# Out:
#                          id          name           artists  \
# 168  03NSuaEAS6MKGzjTti7zhV        Chwiac           Ebauche
# 305  1LKRnFOCwT8NuOuIq1LnzW  Get over You  Lydia Evangeline
# 113  6B8rJlMrDhN9B7BuSKRDXJ       Gateway        Shy Layers
#
#                        genre  acousticness  liveness  instrumentalness  \
# 168            drone ambient         0.836    0.0938          0.903000
# 305           brighton indie         0.746    0.1220          0.000056
# 113  experimental electronic         0.351    0.1420          0.811000
#
#      energy  danceability  valence
# 168   0.358         0.165    0.103
# 305   0.271         0.424    0.216
# 113   0.837         0.663    0.957

# %%
#Extract info about the random selected song
y = df_random_song[['id','name', 
                   'artists',
                   'genre',
                   'acousticness', 
                   'liveness', 
                   'instrumentalness', 
                   'energy', 
                   'danceability', 
                   'valence']]

# %%
y
# Out:
#                         id  name      artists              genre  \
# 33  2nLtzopw4rPReszdYBJU6h  Numb  Linkin Park  alternative metal
#
#     acousticness  liveness  instrumentalness  energy  danceability  valence
# 33        0.0046     0.639               0.0   0.863         0.496    0.243

# %%
# Return 3 recommend songs
df_rec = pd.concat([recommendation,y])
df_rec
# Out:
#                          id          name           artists  \
# 168  03NSuaEAS6MKGzjTti7zhV        Chwiac           Ebauche
# 305  1LKRnFOCwT8NuOuIq1LnzW  Get over You  Lydia Evangeline
# 113  6B8rJlMrDhN9B7BuSKRDXJ       Gateway        Shy Layers
# 33   2nLtzopw4rPReszdYBJU6h          Numb       Linkin Park
#
#                        genre  acousticness  liveness  instrumentalness  \
# 168            drone ambient        0.8360    0.0938          0.903000
# 305           brighton indie        0.7460    0.1220          0.000056
# 113  experimental electronic        0.3510    0.1420          0.811000
# 33         alternative metal        0.0046    0.6390          0.000000
#
#      energy  danceability  valence
# 168   0.358         0.165    0.103
# 305   0.271         0.424    0.216
# 113   0.837         0.663    0.957
# 33    0.863         0.496    0.243

# %% [markdown]
# # End
